# %%
import requests, threading, os, time, pyautogui, csv, pytesseract

import pandas as pd
from pdf2image import convert_from_path
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.action_chains import ActionChains

# %%
shutdown_flag = threading.Event()
def get_hrefs(urls = ['https://www.codot.gov/business/bidding/bid-tab-archives']): #Possibility of collecting also for other years.
    hrefs = []
    for url in urls:
        r = requests.get(url)
        soup = BeautifulSoup(r.text, 'lxml')
        main_content = soup.find('div',{'id' : 'content-core'})
        table =  main_content.find('table')
        for a in table.findAll('a', href=True):
            document_id = a['href'].split('=')[-1]
            if document_id not in [doc.split('=')[-1] for doc in hrefs]: #Avoiding duplication when extracting documents from multiple URLs. 
                hrefs.append(a['href'])
    return(hrefs)

# Split the hrefs list into chunks
def chunk_list(data, num_chunks):
    chunk_size = len(data) // num_chunks
    remainder = len(data) % num_chunks
    chunks = []
    start = 0
    for i in range(num_chunks):
        end = start + chunk_size + (1 if i < remainder else 0)
        chunks.append(data[start:end])
        start = end
    return chunks

# Reuse the setup_driver function
def setup_driver(download_directory, headless=True):
    chrome_options = Options()
    chrome_options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.90 Safari/537.36"
    )
    if headless:
        chrome_options.add_argument("--headless")
    chrome_options.add_argument("--start-maximized")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_experimental_option("prefs", {
        "download.default_directory": download_directory,
        "download.prompt_for_download": False,
        "i": True,
    })
    service = Service(os.path.join(os.getcwd(), "Chromedriver/chromedriver"))
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver

# Function to click at specified coordinates
def click_at_coordinates(driver, x, y):
    try:
        ActionChains(driver).move_by_offset(x, y).click().perform()
        ActionChains(driver).move_by_offset(-x, -y).perform()  # Reset to original position
    except Exception as e:
        print(f"Error performing click at coordinates ({x}, {y}): {e}")

# Function to download PDFs for a worker's chunk
def worker_process(chunk, driver, window_x, window_y, SLEEP=7):
    for href in chunk:
        if shutdown_flag.is_set():
            print(f"Shutdown requested, exiting {href}")
            break

        print(f"Fetching: {href}")
        try:
            driver.get(href)
            time.sleep(SLEEP)

            window_position = driver.get_window_position()
            browser_x = window_position['x']
            browser_y = window_position['y']

            window_size = driver.get_window_size()
            viewport_size = driver.execute_script("return {width: window.innerWidth, height: window.innerHeight};")
            toolbar_height = window_size['height'] - viewport_size['height']

            # Calculate the position inside the window
            ChromeDriver_X = window_x - browser_x
            ChromeDriver_Y = window_y - browser_y - toolbar_height

            click_at_coordinates(driver, ChromeDriver_X, ChromeDriver_Y)
            time.sleep(3)

        except TimeoutException as e:
            print(f"Timeout while processing: {href}. Skipping...")
        except Exception as e:
            print(f"Error occurred with {href}: {e}")

# Multi-threaded function to get PDFs
def get_pdfs_multithread(hrefs, window_x, window_y, max_threads=4, SLEEP=8):
    # Split hrefs into chunks for each worker
    chunks = chunk_list(hrefs, max_threads)
    drivers = [setup_driver(os.path.join(os.getcwd(), "Bidding_Data")) for i in range(max_threads)]

    try:
        with ThreadPoolExecutor(max_threads) as executor:
            # Submit each chunk and its corresponding WebDriver instance
            for chunk, driver in zip(chunks, drivers):
                executor.submit(worker_process, chunk, driver, window_x, window_y, SLEEP)
    except KeyboardInterrupt:
        print("KeyboardInterrupt detected, stopping threads...")
        shutdown_flag.set()  # Notify threads to stop
    finally:
        # Quit all WebDriver instances
        for driver in drivers:
            driver.quit()

def read_pdfs(datafolder, outfile = 'data.csv', split_val = '-', index = 3):
     with open(outfile, 'a', newline='', encoding='utf-8') as c:
        writer = csv.writer(c)
        writer.writerow(['Auction','Num Bids', 'Eng', 'Lowest Bid'] + [f'{i}_bid' for i in range(2, 11)])
        cols = ["Rank", "Vendor Name", "Total Bid"]
        bounding_box = (297, 1290, 2985, 2472)
        files = os.listdir(datafolder)
    
        for file in files:
            pdffile = os.path.join(datafolder, file)
            auction_id = file.split(split_val)[index]
            print(f'Opening {auction_id}')
        
            image = convert_from_path(pdffile, dpi=300, first_page=2, last_page=2)
            try:
                cropped_img = image[0].crop(bounding_box)
            except IndexError as e:
                print(e)
                continue
            raw_text = pytesseract.image_to_string(cropped_img, config="--psm 6")
            rows = raw_text.split("\n")
            table_data = [row.split() for row in rows if row.strip()]
        
            cleaned_data = []
            for row in table_data:
                if len(row) < 3:
                    continue 
                row.pop(1)
                row = row[:-2]
                numeric_idx = next((i for i, val in enumerate(row) if val.replace('.', '', 1).isdigit()), None)
                if numeric_idx is None:
                    continue
                vendor_name = []
                for i in range(numeric_idx + 1, len(row)):
                    if row[i].startswith('$'):
                        dollar_idx = i
                        break
                    vendor_name.append(row[i])
                else:
                    continue 
                vendor_name = " ".join(vendor_name)
                total_bid = "".join(row[dollar_idx:])
                cleaned_row = row[:numeric_idx + 1] + [vendor_name, total_bid]
                cleaned_data.append(cleaned_row)
            try:
                df = pd.DataFrame(cleaned_data, columns=cols)
                df['Total Bid']= df['Total Bid'].str.replace('[\$,]', '', regex=True).astype(float)
                num_bids = df['Rank'].astype(int).max()
                Est = df['Total Bid'][df['Rank'] == '0'].item()
                winning_bid = df['Total Bid'][df['Rank'] == "1"].item()
                if num_bids > 1:
                    ranks = df['Rank'].to_numpy()[(df['Rank'] != '0') & (df['Rank'] != '1')]
                    other_bids = [df['Total Bid'][df['Rank'] == rank].item() for rank in ranks]
            except ValueError as e:
                print(e)
                continue
            print('----------------------------------------------------------------')
            print(f'Auction id: {auction_id}\nNumber of bids: {num_bids}\nWinning bid: {winning_bid}\nOther bids: {other_bids}\nEstimate: {Est}')
            print('----------------------------------------------------------------')
            row = [auction_id, num_bids, Est, winning_bid] + other_bids
            writer.writerow(row)
            other_bids = []

# %%
hrefs = get_hrefs(urls=['https://www.codot.gov/business/bidding/bid-tab-archives',
                        'https://www.codot.gov/business/bidding/bid-tab-archives/2023-bid-tabs/bid-tabs-2023',
                         'https://www.codot.gov/business/bidding/bid-tab-archives/2022-bid-tabs/copy_of_bid-tabs-2022'
                         ])

# %%
#CALIBRATION
print('INSTRUCTIONS\n-----------------------------')
time.sleep(2)
print('The window with the PDF will open in chrome browser. Please hover your mouse on the OPEN button once prompted to do so.')
time.sleep(2)
print('The window will close once the process is complete.')
time.sleep(2)
print('Opening window....')
directory = os.path.join(os.getcwd(), "Bidding_Data")
if not os.path.exists(directory):
        os.makedirs(directory)
driver = setup_driver(directory, headless=False)
driver.get(hrefs[0])
time.sleep(7)
print("Move your mouse to the button. Position will be captured in 5 seconds...")
time.sleep(5)
x, y = pyautogui.position()
print(f"Mouse position: ({x}, {y})")
driver.quit()

# %%
#Download all the pdfs.
get_pdfs_multithread(hrefs, x, y, max_threads=10,SLEEP=8) #Choose threads sensibly.

# %%
#Set the path to the pdf folder.
pdf_folder = 'Bidding_Data'
dir = os.path.join(os.getcwd(), pdf_folder)

# %%
#Retrieve the vendor ranking table from pdfs
read_pdfs(dir, outfile = 'bids1.csv')
# Out:
# Opening  26055
# ----------------------------------------------------------------
# Auction id:  26055
# Number of bids: 2
# Winning bid: 1066564.5
# Other bids: [1231284.0]
# Estimate: 1162614.0
# ----------------------------------------------------------------
# Opening  20912
# ----------------------------------------------------------------
# Auction id:  20912
# Number of bids: 7
# Winning bid: 1747562.65
# Other bids: [1870875.3, 1878649.35, 1889633.0, 2391868.0, 2397750.0, 3325324.0]
# Estimate: 1800000.0
# ----------------------------------------------------------------
# Opening  24881
# ----------------------------------------------------------------
# Auction id:  24881
# Number of bids: 2
# Winning bid: 2924208.0
# Other bids: [3710384.2]
# Estimate: 2536283.06
# ----------------------------------------------------------------
# Opening  24921
# ----------------------------------------------------------------
# Auction id:  24921
# Number of bids: 3
# Winning bid: 2895069.0
# Other bids: [2988158.0, 3898085.16]
# Estimate: 2800000.01
# ----------------------------------------------------------------
# Opening  24063
# ----------------------------------------------------------------
# Auction id:  24063
# Number of bids: 5
# Winning bid: 3618938.3
# Other bids: [3751213.5, 3896707.4, 4150364.02, 4766033.32]
# Estimate: 4626079.2
# ----------------------------------------------------------------
# Opening  24610
# ----------------------------------------------------------------
# Auction id:  24610
# Number of bids: 8
# Winning bid: 45965236.0
# Other bids: [46162718.07, 49334414.86, 49650899.6, 51268186.3, 53722791.56, 58163150.69, 62953677.5]
# Estimate: 39000000.0
# ----------------------------------------------------------------
# Opening  22903
# ----------------------------------------------------------------
# Auction id:  22903
# Number of bids: 2
# Winning bid: 39607433.98
# Other bids: [41898704.82]
# Estimate: 33000000.0
# ----------------------------------------------------------------
# Opening  24935
# ----------------------------------------------------------------
# Auction id:  24935
# Number of bids: 2
# Winning bid: 1636786.0
# Other bids: [2002227.5]
# Estimate: 1500000.0
# ----------------------------------------------------------------
# Opening  24395
# ----------------------------------------------------------------
# Auction id:  24395
# Number of bids: 3
# Winning bid: 10512989.35
# Other bids: [11774728.3, 12895684.35]
# Estimate: 8300000.0
# ----------------------------------------------------------------
# Opening  23601
# ----------------------------------------------------------------
# Auction id:  23601
# Number of bids: 3
# Winning bid: 7017550.0
# Other bids: [7164187.5, 7672202.26]
# Estimate: 9659675.5
# ----------------------------------------------------------------
# Opening  23537
# ----------------------------------------------------------------
# Auction id:  23537
# Number of bids: 4
# Winning bid: 4120979.48
# Other bids: [4209827.39, 4217000.0, 4713173.24]
# Estimate: 3300000.0
# ----------------------------------------------------------------
# Opening  24993
# ----------------------------------------------------------------
# Auction id:  24993
# Number of bids: 4
# Winning bid: 693730.0
# Other bids: [716858.0, 723424.0, 759290.0]
# Estimate: 755500.0
# ----------------------------------------------------------------
# Opening  26355
# ----------------------------------------------------------------
# Auction id:  26355
# Number of bids: 1
# Winning bid: 1674070.3
# Other bids: []
# Estimate: 1681461.8
# ----------------------------------------------------------------
# Opening  24224
# ----------------------------------------------------------------
# Auction id:  24224
# Number of bids: 6
# Winning bid: 8981782.6
# Other bids: [8993737.0, 11516040.0, 11714615.02, 11969290.67, 13752936.39]
# Estimate: 7775000.0
# ----------------------------------------------------------------
# Opening  24199
# ----------------------------------------------------------------
# Auction id:  24199
# Number of bids: 6
# Winning bid: 5486435.9
# Other bids: [5988706.0, 5997909.19, 6735430.2, 6934593.58, 7258182.84]
# Estimate: 5715000.0
# ----------------------------------------------------------------
# Opening  25137
# ----------------------------------------------------------------
# Auction id:  25137
# Number of bids: 3
# Winning bid: 1548999.0
# Other bids: [1767901.0, 2304736.0]
# Estimate: 2134570.0
# ----------------------------------------------------------------
# Opening  25850
# ----------------------------------------------------------------
# Auction id:  25850
# Number of bids: 3
# Winning bid: 1887265.0
# Other bids: [1903178.5, 4908460.0]
# Estimate: 1892184.0
# ----------------------------------------------------------------
# Opening  22193
# ----------------------------------------------------------------
# Auction id:  22193
# Number of bids: 2
# Winning bid: 21890679.16
# Other bids: [22350277.47]
# Estimate: 18113461.21
# ----------------------------------------------------------------
# Opening  26036
# ----------------------------------------------------------------
# Auction id:  26036
# Number of bids: 2
# Winning bid: 555495.0
# Other bids: [580075.0]
# Estimate: 442975.0
# ----------------------------------------------------------------
# Opening  26244
# ----------------------------------------------------------------
# Auction id:  26244
# Number of bids: 1
# Winning bid: 2493062.25
# Other bids: []
# Estimate: 2900000.0
# ----------------------------------------------------------------
# Opening  25120
# ----------------------------------------------------------------
# Auction id:  25120
# Number of bids: 2
# Winning bid: 545861.5
# Other bids: [690000.0]
# Estimate: 486879.0
# ----------------------------------------------------------------
# Opening  21855
# ----------------------------------------------------------------
# Auction id:  21855
# Number of bids: 5
# Winning bid: 3098847.35
# Other bids: [3436044.03, 3704833.05, 3799846.03, 4180771.0]
# Estimate: 3663682.58
# ----------------------------------------------------------------
# Opening  24229
# ----------------------------------------------------------------
# Auction id:  24229
# Number of bids: 2
# Winning bid: 7080420.17
# Other bids: [9187457.25]
# Estimate: 10569308.7
# ----------------------------------------------------------------
# Opening  21400
# ----------------------------------------------------------------
# Auction id:  21400
# Number of bids: 2
# Winning bid: 5635899.39
# Other bids: [6785575.3]
# Estimate: 5700000.0
# ----------------------------------------------------------------
# Opening  25295
# ----------------------------------------------------------------
# Auction id:  25295
# Number of bids: 1
# Winning bid: 414867.88
# Other bids: []
# Estimate: 441058.75
# ----------------------------------------------------------------
# Opening  23612
# ----------------------------------------------------------------
# Auction id:  23612
# Number of bids: 3
# Winning bid: 1540725.1
# Other bids: [1558047.29, 1559306.2]
# Estimate: 1244890.0
# ----------------------------------------------------------------
# Opening  22020
# ----------------------------------------------------------------
# Auction id:  22020
# Number of bids: 3
# Winning bid: 18991815.84
# Other bids: [19214445.92, 19763385.05]
# Estimate: 19126443.5
# ----------------------------------------------------------------
# Opening  25942
# ----------------------------------------------------------------
# Auction id:  25942
# Number of bids: 3
# Winning bid: 7902793.1
# Other bids: [8123624.51, 9448792.45]
# Estimate: 9017854.0
# ----------------------------------------------------------------
# Opening  26270
# ----------------------------------------------------------------
# Auction id:  26270
# Number of bids: 5
# Winning bid: 1848479.0
# Other bids: [1903212.0, 1921453.0, 1999027.82, 2152047.25]
# Estimate: 1900000.0
# ----------------------------------------------------------------
# Opening  24971
# ----------------------------------------------------------------
# Auction id:  24971
# Number of bids: 2
# Winning bid: 12661159.85
# Other bids: [14304073.99]
# Estimate: 13281298.5
# ----------------------------------------------------------------
# Opening  25071
# ----------------------------------------------------------------
# Auction id:  25071
# Number of bids: 3
# Winning bid: 4080829.29
# Other bids: [4208925.96, 4566597.19]
# Estimate: 4500000.01
# ----------------------------------------------------------------
# Opening  22992
# ----------------------------------------------------------------
# Auction id:  22992
# Number of bids: 1
# Winning bid: 12263410.53
# Other bids: []
# Estimate: 11367503.0
# ----------------------------------------------------------------
# Opening  26419
# ----------------------------------------------------------------
# Auction id:  26419
# Number of bids: 1
# Winning bid: 986914.05
# Other bids: []
# Estimate: 1138965.0
# ----------------------------------------------------------------
# Opening  25538
# ----------------------------------------------------------------
# Auction id:  25538
# Number of bids: 6
# Winning bid: 2321547.11
# Other bids: [2324631.63, 2448554.41, 2502429.82, 2678540.03, 2765999.0]
# Estimate: 3500000.0
# ----------------------------------------------------------------
# Opening  25279
# ----------------------------------------------------------------
# Auction id:  25279
# Number of bids: 2
# Winning bid: 438107.0
# Other bids: [446920.0]
# Estimate: 680282.5
# ----------------------------------------------------------------
# Opening  26438
# ----------------------------------------------------------------
# Auction id:  26438
# Number of bids: 5
# Winning bid: 784132.96
# Other bids: [991400.0, 1090698.0, 1264995.0, 1481853.0]
# Estimate: 1000000.0
# ----------------------------------------------------------------
# Opening  24208
# ----------------------------------------------------------------
# Auction id:  24208
# Number of bids: 3
# Winning bid: 14314966.6
# Other bids: [16399849.41, 17669719.4]
# Estimate: 16818052.0
# ----------------------------------------------------------------
# Opening  24414
# ----------------------------------------------------------------
# Auction id:  24414
# Number of bids: 1
# Winning bid: 5520588.7
# Other bids: []
# Estimate: 5136933.22
# ----------------------------------------------------------------
# Opening  24394
# ----------------------------------------------------------------
# Auction id:  24394
# Number of bids: 1
# Winning bid: 1186600.16
# Other bids: []
# Estimate: 1206000.0
# ----------------------------------------------------------------
# Opening  24646
# ----------------------------------------------------------------
# Auction id:  24646
# Number of bids: 5
# Winning bid: 670297.0
# Other bids: [804689.5, 884884.0, 1098141.25, 1269720.0]
# Estimate: 1100000.0
# ----------------------------------------------------------------
# Opening  25668
# ----------------------------------------------------------------
# Auction id:  25668
# Number of bids: 2
# Winning bid: 1222402.0
# Other bids: [1812714.0]
# Estimate: 1001306.38
# ----------------------------------------------------------------
# Opening  24795
# ----------------------------------------------------------------
# Auction id:  24795
# Number of bids: 3
# Winning bid: 558097.5
# Other bids: [649999.0, 669129.0]
# Estimate: 474860.0
# ----------------------------------------------------------------
# Opening  25293
# ----------------------------------------------------------------
# Auction id:  25293
# Number of bids: 5
# Winning bid: 1646566.34
# Other bids: [1649635.2, 2128148.6, 2222428.0, 2329649.39]
# Estimate: 1703392.84
# ----------------------------------------------------------------
# Opening  22036
# ----------------------------------------------------------------
# Auction id:  22036
# Number of bids: 5
# Winning bid: 5441723.08
# Other bids: [5572733.6, 5956425.4, 6335184.98, 6642699.0]
# Estimate: 5261535.0
# ----------------------------------------------------------------
# Opening  24412
# ----------------------------------------------------------------
# Auction id:  24412
# Number of bids: 1
# Winning bid: 749206.0
# Other bids: []
# Estimate: 1100007.0
# ----------------------------------------------------------------
# Opening  24167
# ----------------------------------------------------------------
# Auction id:  24167
# Number of bids: 1
# Winning bid: 1194545.0
# Other bids: []
# Estimate: 892580.0
# ----------------------------------------------------------------
# Opening  20923
# can only convert an array of size 1 to a Python scalar
# Opening  24639
# ----------------------------------------------------------------
# Auction id:  24639
# Number of bids: 5
# Winning bid: 1992436.8
# Other bids: [2151653.81, 3115089.9, 3361362.85, 3477938.9]
# Estimate: 2000000.0
# ----------------------------------------------------------------
# Opening  23688
# ----------------------------------------------------------------
# Auction id:  23688
# Number of bids: 2
# Winning bid: 693896.87
# Other bids: [1065888.0]
# Estimate: 700000.0
# ----------------------------------------------------------------
# Opening  25276
# ----------------------------------------------------------------
# Auction id:  25276
# Number of bids: 1
# Winning bid: 2989418.49
# Other bids: []
# Estimate: 3000000.0
# ----------------------------------------------------------------
# Opening  24872
# ----------------------------------------------------------------
# Auction id:  24872
# Number of bids: 1
# Winning bid: 2745838.9
# Other bids: []
# Estimate: 2105230.0
# ----------------------------------------------------------------
# Opening  20986
# ----------------------------------------------------------------
# Auction id:  20986
# Number of bids: 4
# Winning bid: 3780958.22
# Other bids: [4611545.74, 4681167.7, 5139925.4]
# Estimate: 4800000.0
# ----------------------------------------------------------------
# Opening  22338
# ----------------------------------------------------------------
# Auction id:  22338
# Number of bids: 4
# Winning bid: 4977656.25
# Other bids: [7474337.0, 7526451.86, 7811688.6]
# Estimate: 4600000.0
# ----------------------------------------------------------------
# Opening  23817
# ----------------------------------------------------------------
# Auction id:  23817
# Number of bids: 3
# Winning bid: 8656532.96
# Other bids: [9472053.36, 10610155.6]
# Estimate: 10200000.0
# ----------------------------------------------------------------
# Opening  24673
# ----------------------------------------------------------------
# Auction id:  24673
# Number of bids: 2
# Winning bid: 1469215.0
# Other bids: [2414592.0]
# Estimate: 1323794.0
# ----------------------------------------------------------------
# Opening  25817
# ----------------------------------------------------------------
# Auction id:  25817
# Number of bids: 1
# Winning bid: 4074430.23
# Other bids: []
# Estimate: 4200000.0
# ----------------------------------------------------------------
# Opening  24994
# ----------------------------------------------------------------
# Auction id:  24994
# Number of bids: 3
# Winning bid: 324225.0
# Other bids: [378125.0, 400750.0]
# Estimate: 362500.0
# ----------------------------------------------------------------
# Opening  26262
# ----------------------------------------------------------------
# Auction id:  26262
# Number of bids: 3
# Winning bid: 513949.0
# Other bids: [574612.0, 974786.0]
# Estimate: 687800.0
# ----------------------------------------------------------------
# Opening  23327
# ----------------------------------------------------------------
# Auction id:  23327
# Number of bids: 4
# Winning bid: 5039495.35
# Other bids: [5769288.05, 6664213.9, 6852458.8]
# Estimate: 6655701.0
# ----------------------------------------------------------------
# Opening  25478
# ----------------------------------------------------------------
# Auction id:  25478
# Number of bids: 1
# Winning bid: 4923812.7
# Other bids: []
# Estimate: 4000000.0
# ----------------------------------------------------------------
# Opening  23115
# ----------------------------------------------------------------
# Auction id:  23115
# Number of bids: 1
# Winning bid: 2240000.0
# Other bids: []
# Estimate: 2700000.0
# ----------------------------------------------------------------
# Opening  24416
# ----------------------------------------------------------------
# Auction id:  24416
# Number of bids: 2
# Winning bid: 916269.0
# Other bids: [921504.39]
# Estimate: 664000.0
# ----------------------------------------------------------------
# Opening  23535
# ----------------------------------------------------------------
# Auction id:  23535
# Number of bids: 4
# Winning bid: 105158918.35
# Other bids: [119757640.95, 120156691.1, 144805137.0]
# Estimate: 100925098.67
# ----------------------------------------------------------------
# Opening  25016
# ----------------------------------------------------------------
# Auction id:  25016
# Number of bids: 3
# Winning bid: 448255.86
# Other bids: [565395.11, 733399.6]
# Estimate: 479500.0
# ----------------------------------------------------------------
# Opening  21591
# ----------------------------------------------------------------
# Auction id:  21591
# Number of bids: 2
# Winning bid: 4696233.75
# Other bids: [6134493.89]
# Estimate: 4200000.0
# ----------------------------------------------------------------
# Opening  25354
# ----------------------------------------------------------------
# Auction id:  25354
# Number of bids: 4
# Winning bid: 2131163.07
# Other bids: [2295285.0, 2433385.5, 2604226.6]
# Estimate: 1600860.0
# ----------------------------------------------------------------
# Opening  22702
# ----------------------------------------------------------------
# Auction id:  22702
# Number of bids: 1
# Winning bid: 1096643.8
# Other bids: []
# Estimate: 1149370.0
# ----------------------------------------------------------------
# Opening  24509
# ----------------------------------------------------------------
# Auction id:  24509
# Number of bids: 4
# Winning bid: 2497837.0
# Other bids: [2947473.8, 3180448.1, 4583220.76]
# Estimate: 2975099.0
# ----------------------------------------------------------------
# Opening  24200
# ----------------------------------------------------------------
# Auction id:  24200
# Number of bids: 5
# Winning bid: 5111254.25
# Other bids: [5123803.35, 5331754.25, 5929921.95, 6399435.15]
# Estimate: 6864851.67
# ----------------------------------------------------------------
# Opening  24171
# ----------------------------------------------------------------
# Auction id:  24171
# Number of bids: 3
# Winning bid: 6877563.45
# Other bids: [7321935.95, 9486863.0]
# Estimate: 5883600.0
# ----------------------------------------------------------------
# Opening  21222
# ----------------------------------------------------------------
# Auction id:  21222
# Number of bids: 3
# Winning bid: 3070798.76
# Other bids: [3331598.12, 3412108.0]
# Estimate: 2300000.0
# ----------------------------------------------------------------
# Opening  20896
# ----------------------------------------------------------------
# Auction id:  20896
# Number of bids: 4
# Winning bid: 2827827.0
# Other bids: [3298552.0, 3420596.61, 3597574.0]
# Estimate: 3000000.0
# ----------------------------------------------------------------
# Opening  24884
# ----------------------------------------------------------------
# Auction id:  24884
# Number of bids: 3
# Winning bid: 17339986.92
# Other bids: [19134061.25, 19502109.81]
# Estimate: 15000000.0
# ----------------------------------------------------------------
# Opening  23698
# ----------------------------------------------------------------
# Auction id:  23698
# Number of bids: 5
# Winning bid: 1853073.44
# Other bids: [2086400.0, 2137416.0, 2283705.01, 3425024.0]
# Estimate: 1600000.0
# ----------------------------------------------------------------
# Opening  25140
# ----------------------------------------------------------------
# Auction id:  25140
# Number of bids: 5
# Winning bid: 2545678.1
# Other bids: [2569727.5, 2678575.8, 2858528.01, 3273284.69]
# Estimate: 3100000.0
# ----------------------------------------------------------------
# Opening  24667
# ----------------------------------------------------------------
# Auction id:  24667
# Number of bids: 3
# Winning bid: 6596527.0
# Other bids: [6799770.0, 7018649.74]
# Estimate: 5504571.43
# ----------------------------------------------------------------
# Opening  24015
# ----------------------------------------------------------------
# Auction id:  24015
# Number of bids: 3
# Winning bid: 4956044.15
# Other bids: [6099999.0, 7789750.02]
# Estimate: 4047501.0
# ----------------------------------------------------------------
# Opening  23623
# ----------------------------------------------------------------
# Auction id:  23623
# Number of bids: 2
# Winning bid: 744942.0
# Other bids: [766961.0]
# Estimate: 560775.0
# ----------------------------------------------------------------
# Opening  26328
# ----------------------------------------------------------------
# Auction id:  26328
# Number of bids: 3
# Winning bid: 505000.0
# Other bids: [565130.0, 690420.0]
# Estimate: 650680.0
# ----------------------------------------------------------------
# Opening  24666
# ----------------------------------------------------------------
# Auction id:  24666
# Number of bids: 7
# Winning bid: 9900432.72
# Other bids: [10326840.5, 10827181.4, 11596000.0, 11985226.25, 12152417.02, 15781467.1]
# Estimate: 10000000.0
# ----------------------------------------------------------------
# Opening  25524
# ----------------------------------------------------------------
# Auction id:  25524
# Number of bids: 3
# Winning bid: 328376.56
# Other bids: [414591.0, 470646.0]
# Estimate: 385000.0
# ----------------------------------------------------------------
# Opening  24092
# ----------------------------------------------------------------
# Auction id:  24092
# Number of bids: 2
# Winning bid: 14126484.41
# Other bids: [14384518.38]
# Estimate: 13293410.95
# ----------------------------------------------------------------
# Opening  23544
# ----------------------------------------------------------------
# Auction id:  23544
# Number of bids: 8
# Winning bid: 1697000.0
# Other bids: [1705746.68, 1798898.0, 1938274.5, 1986115.71, 2132997.3, 2134051.0, 2220066.0]
# Estimate: 2100000.0
# ----------------------------------------------------------------
# Opening  22547
# ----------------------------------------------------------------
# Auction id:  22547
# Number of bids: 8
# Winning bid: 13166577.55
# Other bids: [14449351.84, 14820130.1, 14872670.35, 15577074.45, 16296445.93, 17252092.63, 20114461.9]
# Estimate: 12994800.0
# ----------------------------------------------------------------
# Opening  23475
# ----------------------------------------------------------------
# Auction id:  23475
# Number of bids: 2
# Winning bid: 9490148.53
# Other bids: [9636645.21]
# Estimate: 10036403.05
# ----------------------------------------------------------------
# Opening  24032
# ----------------------------------------------------------------
# Auction id:  24032
# Number of bids: 6
# Winning bid: 1223303.25
# Other bids: [1254660.5, 1292605.55, 1374985.0, 1396713.0, 1409515.0]
# Estimate: 1200000.0
# ----------------------------------------------------------------
# Opening  23871
# ----------------------------------------------------------------
# Auction id:  23871
# Number of bids: 3
# Winning bid: 748495.0
# Other bids: [855383.0, 1112035.87]
# Estimate: 760000.0
# ----------------------------------------------------------------
# Opening  20169
# ----------------------------------------------------------------
# Auction id:  20169
# Number of bids: 4
# Winning bid: 6735433.99
# Other bids: [7155000.0, 9244165.0, 9827284.1]
# Estimate: 8250688.0
# ----------------------------------------------------------------
# Opening  21472
# ----------------------------------------------------------------
# Auction id:  21472
# Number of bids: 4
# Winning bid: 12879789.35
# Other bids: [13342317.86, 13874102.7, 14211843.0]
# Estimate: 9596980.0
# ----------------------------------------------------------------
# Opening  25035
# ----------------------------------------------------------------
# Auction id:  25035
# Number of bids: 3
# Winning bid: 1518388.73
# Other bids: [1579977.13, 2312223.75]
# Estimate: 1558896.85
# ----------------------------------------------------------------
# Opening  26352
# ----------------------------------------------------------------
# Auction id:  26352
# Number of bids: 3
# Winning bid: 2893852.87
# Other bids: [3115025.43, 3245086.62]
# Estimate: 3350000.0
# ----------------------------------------------------------------
# Opening  24951
# ----------------------------------------------------------------
# Auction id:  24951
# Number of bids: 2
# Winning bid: 646748.0
# Other bids: [713824.0]
# Estimate: 830000.0
# ----------------------------------------------------------------
# Opening  23971
# ----------------------------------------------------------------
# Auction id:  23971
# Number of bids: 3
# Winning bid: 289870.0
# Other bids: [372099.0, 495955.7]
# Estimate: 353040.0
# ----------------------------------------------------------------
# Opening  24672
# ----------------------------------------------------------------
# Auction id:  24672
# Number of bids: 2
# Winning bid: 244433.0
# Other bids: [258782.0]
# Estimate: 235000.0
# ----------------------------------------------------------------
# Opening  23110
# ----------------------------------------------------------------
# Auction id:  23110
# Number of bids: 2
# Winning bid: 9208179.5
# Other bids: [10121937.7]
# Estimate: 7348166.0
# ----------------------------------------------------------------
# Opening  25561
# ----------------------------------------------------------------
# Auction id:  25561
# Number of bids: 2
# Winning bid: 7438813.0
# Other bids: [7563838.0]
# Estimate: 7800000.0
# ----------------------------------------------------------------
# Opening  24894
# ----------------------------------------------------------------
# Auction id:  24894
# Number of bids: 1
# Winning bid: 47957757.02
# Other bids: []
# Estimate: 47957757.02
# ----------------------------------------------------------------
# Opening  22381
# ----------------------------------------------------------------
# Auction id:  22381
# Number of bids: 5
# Winning bid: 26917300.0
# Other bids: [26956035.93, 27272031.05, 31297035.57, 34311607.82]
# Estimate: 22562575.75
# ----------------------------------------------------------------
# Opening  25037
# ----------------------------------------------------------------
# Auction id:  25037
# Number of bids: 4
# Winning bid: 20899040.68
# Other bids: [21548702.5, 24732732.0, 25898971.88]
# Estimate: 20636218.7
# ----------------------------------------------------------------
# Opening  26054
# ----------------------------------------------------------------
# Auction id:  26054
# Number of bids: 5
# Winning bid: 1388960.34
# Other bids: [1523287.0, 1609230.96, 2075365.0, 2166235.21]
# Estimate: 1765000.0
# ----------------------------------------------------------------
# Opening  24247
# ----------------------------------------------------------------
# Auction id:  24247
# Number of bids: 3
# Winning bid: 3297815.15
# Other bids: [4645511.22, 4675576.0]
# Estimate: 3591117.4
# ----------------------------------------------------------------
# Opening  24769
# ----------------------------------------------------------------
# Auction id:  24769
# Number of bids: 4
# Winning bid: 1564170.0
# Other bids: [1802409.14, 2127817.3, 2477811.8]
# Estimate: 1541657.3
# ----------------------------------------------------------------
# Opening  20706
# ----------------------------------------------------------------
# Auction id:  20706
# Number of bids: 3
# Winning bid: 1400000.0
# Other bids: [1758282.0, 1905226.73]
# Estimate: 1616536.5
# ----------------------------------------------------------------
# Opening  24198
# ----------------------------------------------------------------
# Auction id:  24198
# Number of bids: 2
# Winning bid: 5695695.99
# Other bids: [6041043.79]
# Estimate: 5800000.0
# ----------------------------------------------------------------
# Opening  24193
# ----------------------------------------------------------------
# Auction id:  24193
# Number of bids: 3
# Winning bid: 12723069.27
# Other bids: [13739043.0, 14232481.52]
# Estimate: 10300000.0
# ----------------------------------------------------------------
# Opening  25974
# ----------------------------------------------------------------
# Auction id:  25974
# Number of bids: 6
# Winning bid: 1520811.25
# Other bids: [1734732.64, 2170921.38, 2252054.45, 2635000.0, 3440532.5]
# Estimate: 1536691.92
# ----------------------------------------------------------------
# Opening  24142
# ----------------------------------------------------------------
# Auction id:  24142
# Number of bids: 2
# Winning bid: 3855000.0
# Other bids: [4408564.0]
# Estimate: 4818686.0
# ----------------------------------------------------------------
# Opening  25277
# ----------------------------------------------------------------
# Auction id:  25277
# Number of bids: 4
# Winning bid: 2191362.0
# Other bids: [2447092.67, 2513561.4, 3551486.5]
# Estimate: 3096405.3
# ----------------------------------------------------------------
# Opening  21801
# ----------------------------------------------------------------
# Auction id:  21801
# Number of bids: 4
# Winning bid: 4704411.4
# Other bids: [5395010.32, 5679258.64, 6300630.0]
# Estimate: 4400000.0
# ----------------------------------------------------------------
# Opening  24955
# ----------------------------------------------------------------
# Auction id:  24955
# Number of bids: 2
# Winning bid: 2089265.0
# Other bids: [2181900.0]
# Estimate: 1945075.0
# ----------------------------------------------------------------
# Opening  24477
# ----------------------------------------------------------------
# Auction id:  24477
# Number of bids: 2
# Winning bid: 2118114.0
# Other bids: [3005795.0]
# Estimate: 1603530.0
# ----------------------------------------------------------------
# Opening  23064
# ----------------------------------------------------------------
# Auction id:  23064
# Number of bids: 1
# Winning bid: 715000.0
# Other bids: []
# Estimate: 616297.0
# ----------------------------------------------------------------
# Opening  22629
# ----------------------------------------------------------------
# Auction id:  22629
# Number of bids: 4
# Winning bid: 5098771.0
# Other bids: [5500000.0, 5637292.79, 6234491.16]
# Estimate: 4821014.95
# ----------------------------------------------------------------
# Opening  23592
# ----------------------------------------------------------------
# Auction id:  23592
# Number of bids: 2
# Winning bid: 6154075.8
# Other bids: [6556359.85]
# Estimate: 7000000.0
# ----------------------------------------------------------------
# Opening  24885
# ----------------------------------------------------------------
# Auction id:  24885
# Number of bids: 4
# Winning bid: 1190000.0
# Other bids: [1269499.15, 1415585.0, 1432583.0]
# Estimate: 1372536.0
# ----------------------------------------------------------------
# Opening  24772
# ----------------------------------------------------------------
# Auction id:  24772
# Number of bids: 1
# Winning bid: 1634083.0
# Other bids: []
# Estimate: 1303223.0
# ----------------------------------------------------------------
# Opening  24678
# ----------------------------------------------------------------
# Auction id:  24678
# Number of bids: 2
# Winning bid: 7750316.1
# Other bids: [8193117.3]
# Estimate: 8714550.0
# ----------------------------------------------------------------
# Opening  23505
# ----------------------------------------------------------------
# Auction id:  23505
# Number of bids: 1
# Winning bid: 9280171.97
# Other bids: []
# Estimate: 9382218.0
# ----------------------------------------------------------------
# Opening  24405
# ----------------------------------------------------------------
# Auction id:  24405
# Number of bids: 1
# Winning bid: 4432957.09
# Other bids: []
# Estimate: 4302838.72
# ----------------------------------------------------------------
# Opening  23468
# ----------------------------------------------------------------
# Auction id:  23468
# Number of bids: 4
# Winning bid: 13997628.23
# Other bids: [14120306.41, 14206995.65, 15278130.15]
# Estimate: 12800000.0
# ----------------------------------------------------------------
# Opening  24670
# ----------------------------------------------------------------
# Auction id:  24670
# Number of bids: 3
# Winning bid: 9157473.0
# Other bids: [9922134.5, 10522532.11]
# Estimate: 8350901.0
# ----------------------------------------------------------------
# Opening  26275
# ----------------------------------------------------------------
# Auction id:  26275
# Number of bids: 1
# Winning bid: 15719271.04
# Other bids: []
# Estimate: 16000000.0
# ----------------------------------------------------------------
# Opening  20909
# can only convert an array of size 1 to a Python scalar
# Opening  25317
# ----------------------------------------------------------------
# Auction id:  25317
# Number of bids: 4
# Winning bid: 1291761.85
# Other bids: [1710063.25, 1795399.4, 2256216.5]
# Estimate: 1000000.0
# ----------------------------------------------------------------
# Opening  24037
# ----------------------------------------------------------------
# Auction id:  24037
# Number of bids: 3
# Winning bid: 174037.0
# Other bids: [245313.0, 246659.3]
# Estimate: 165064.5
# ----------------------------------------------------------------
# Opening  23061
# ----------------------------------------------------------------
# Auction id:  23061
# Number of bids: 3
# Winning bid: 10674323.88
# Other bids: [11312500.0, 11964668.25]
# Estimate: 12005294.3
# ----------------------------------------------------------------
# Opening  24544
# ----------------------------------------------------------------
# Auction id:  24544
# Number of bids: 2
# Winning bid: 7922323.51
# Other bids: [8104990.0]
# Estimate: 10443474.0
# ----------------------------------------------------------------
# Opening  25447
# ----------------------------------------------------------------
# Auction id:  25447
# Number of bids: 1
# Winning bid: 4185920.67
# Other bids: []
# Estimate: 4093739.61
# ----------------------------------------------------------------
# Opening  23758
# ----------------------------------------------------------------
# Auction id:  23758
# Number of bids: 4
# Winning bid: 4430539.3
# Other bids: [5573850.0, 6632188.0, 6707410.5]
# Estimate: 4799153.0
# ----------------------------------------------------------------
# Opening  25859
# ----------------------------------------------------------------
# Auction id:  25859
# Number of bids: 4
# Winning bid: 15810821.36
# Other bids: [16986300.91, 17257000.0, 18417097.1]
# Estimate: 16500000.0
# ----------------------------------------------------------------
# Opening  20960
# ----------------------------------------------------------------
# Auction id:  20960
# Number of bids: 3
# Winning bid: 6056197.46
# Other bids: [6099750.0, 6793415.65]
# Estimate: 5717768.5
# ----------------------------------------------------------------
# Opening  23873
# ----------------------------------------------------------------
# Auction id:  23873
# Number of bids: 4
# Winning bid: 679000.0
# Other bids: [789151.0, 846200.75, 1135986.0]
# Estimate: 765675.0
# ----------------------------------------------------------------
# Opening  24954
# ----------------------------------------------------------------
# Auction id:  24954
# Number of bids: 2
# Winning bid: 4806630.45
# Other bids: [5539841.35]
# Estimate: 6085432.65
# ----------------------------------------------------------------
# Opening  24878
# ----------------------------------------------------------------
# Auction id:  24878
# Number of bids: 4
# Winning bid: 2475000.0
# Other bids: [2787162.0, 2841622.0, 3374031.9]
# Estimate: 3600000.0
# ----------------------------------------------------------------
# Opening  24599
# ----------------------------------------------------------------
# Auction id:  24599
# Number of bids: 2
# Winning bid: 3369252.14
# Other bids: [6295034.0]
# Estimate: 3570928.5
# ----------------------------------------------------------------
# Opening  26343
# ----------------------------------------------------------------
# Auction id:  26343
# Number of bids: 3
# Winning bid: 443963.2
# Other bids: [504026.01, 646179.6]
# Estimate: 498720.8
# ----------------------------------------------------------------
# Opening  23443
# ----------------------------------------------------------------
# Auction id:  23443
# Number of bids: 3
# Winning bid: 1742097.0
# Other bids: [2623501.0, 3906556.0]
# Estimate: 2099909.0
# ----------------------------------------------------------------
# Opening  22465
# ----------------------------------------------------------------
# Auction id:  22465
# Number of bids: 1
# Winning bid: 12796063.7
# Other bids: []
# Estimate: 11000000.0
# ----------------------------------------------------------------
# Opening  26578
# ----------------------------------------------------------------
# Auction id:  26578
# Number of bids: 5
# Winning bid: 423380.0
# Other bids: [508852.0, 672607.0, 762655.0, 987620.0]
# Estimate: 600000.0
# ----------------------------------------------------------------
# Opening  23019
# ----------------------------------------------------------------
# Auction id:  23019
# Number of bids: 1
# Winning bid: 6514608.17
# Other bids: []
# Estimate: 5822199.44
# ----------------------------------------------------------------
# Opening  23499
# ----------------------------------------------------------------
# Auction id:  23499
# Number of bids: 2
# Winning bid: 6686562.84
# Other bids: [7778375.35]
# Estimate: 6808711.0
# ----------------------------------------------------------------
# Opening  25205
# ----------------------------------------------------------------
# Auction id:  25205
# Number of bids: 1
# Winning bid: 3801536.05
# Other bids: []
# Estimate: 3935750.0
# ----------------------------------------------------------------
# Opening  23292
# ----------------------------------------------------------------
# Auction id:  23292
# Number of bids: 2
# Winning bid: 2854417.85
# Other bids: [3206988.7]
# Estimate: 2300000.0
# ----------------------------------------------------------------
# Opening  21556
# ----------------------------------------------------------------
# Auction id:  21556
# Number of bids: 3
# Winning bid: 22317300.0
# Other bids: [24836000.0, 26542435.32]
# Estimate: 24639386.9
# ----------------------------------------------------------------
# Opening  26311
# ----------------------------------------------------------------
# Auction id:  26311
# Number of bids: 3
# Winning bid: 4877179.8
# Other bids: [5156048.77, 5170025.6]
# Estimate: 4600000.0
# ----------------------------------------------------------------
# Opening  23697
# ----------------------------------------------------------------
# Auction id:  23697
# Number of bids: 3
# Winning bid: 6997892.42
# Other bids: [7557886.15, 10309324.9]
# Estimate: 7000000.0
# ----------------------------------------------------------------
# Opening  25166
# ----------------------------------------------------------------
# Auction id:  25166
# Number of bids: 1
# Winning bid: 3507949.39
# Other bids: []
# Estimate: 3253459.13
# ----------------------------------------------------------------
# Opening  25444
# ----------------------------------------------------------------
# Auction id:  25444
# Number of bids: 2
# Winning bid: 2546291.82
# Other bids: [2584400.94]
# Estimate: 2919144.5
# ----------------------------------------------------------------
# Opening  22529
# ----------------------------------------------------------------
# Auction id:  22529
# Number of bids: 7
# Winning bid: 19126166.0
# Other bids: [19225000.0, 19344459.22, 19880000.0, 20148369.5, 20179169.65, 21327291.4]
# Estimate: 20447908.0
# ----------------------------------------------------------------
# Opening  25124
# ----------------------------------------------------------------
# Auction id:  25124
# Number of bids: 3
# Winning bid: 1476110.2
# Other bids: [1645492.36, 2137308.12]
# Estimate: 1644264.23
# ----------------------------------------------------------------
# Opening  24658
# ----------------------------------------------------------------
# Auction id:  24658
# Number of bids: 3
# Winning bid: 4128231.0
# Other bids: [5473317.6, 5775782.47]
# Estimate: 4220600.0
# ----------------------------------------------------------------
# Opening  24887
# ----------------------------------------------------------------
# Auction id:  24887
# Number of bids: 6
# Winning bid: 11942392.41
# Other bids: [13381330.9, 13896804.68, 16281746.84, 16708777.0, 18418236.81]
# Estimate: 16087610.3
# ----------------------------------------------------------------
# Opening  23191
# ----------------------------------------------------------------
# Auction id:  23191
# Number of bids: 2
# Winning bid: 2095832.0
# Other bids: [2903962.13]
# Estimate: 2003463.75
# ----------------------------------------------------------------
# Opening  25708
# ----------------------------------------------------------------
# Auction id:  25708
# Number of bids: 3
# Winning bid: 3295983.8
# Other bids: [3353299.48, 3786709.06]
# Estimate: 3429000.0
# ----------------------------------------------------------------
# Opening  22247
# ----------------------------------------------------------------
# Auction id:  22247
# Number of bids: 3
# Winning bid: 2097272.44
# Other bids: [2175163.17, 2453158.8]
# Estimate: 1900000.0
# ----------------------------------------------------------------
# Opening  0
# list index out of range
# Opening  21191
# ----------------------------------------------------------------
# Auction id:  21191
# Number of bids: 3
# Winning bid: 6049464.37
# Other bids: [6119885.5, 6754762.0]
# Estimate: 6000000.0
# ----------------------------------------------------------------
# Opening  25855
# ----------------------------------------------------------------
# Auction id:  25855
# Number of bids: 2
# Winning bid: 2887896.79
# Other bids: [3767948.0]
# Estimate: 3460110.0
# ----------------------------------------------------------------
# Opening  26617
# ----------------------------------------------------------------
# Auction id:  26617
# Number of bids: 2
# Winning bid: 637922.5
# Other bids: [643227.0]
# Estimate: 610000.0
# ----------------------------------------------------------------
# Opening  24966
# ----------------------------------------------------------------
# Auction id:  24966
# Number of bids: 2
# Winning bid: 512963.0
# Other bids: [538688.0]
# Estimate: 502057.0
# ----------------------------------------------------------------
# Opening  24770
# ----------------------------------------------------------------
# Auction id:  24770
# Number of bids: 2
# Winning bid: 1168613.0
# Other bids: [1440759.15]
# Estimate: 1331712.5
# ----------------------------------------------------------------
# Opening  24166
# ----------------------------------------------------------------
# Auction id:  24166
# Number of bids: 2
# Winning bid: 6632329.84
# Other bids: [8293025.45]
# Estimate: 6856967.1
# ----------------------------------------------------------------
# Opening  24403
# can only convert an array of size 1 to a Python scalar
# Opening  24905
# ----------------------------------------------------------------
# Auction id:  24905
# Number of bids: 2
# Winning bid: 36536568.67
# Other bids: [46054100.3]
# Estimate: 36528643.2
# ----------------------------------------------------------------
# Opening  23583
# ----------------------------------------------------------------
# Auction id:  23583
# Number of bids: 1
# Winning bid: 19290622.35
# Other bids: []
# Estimate: 18685169.05
# ----------------------------------------------------------------
# Opening  24039
# ----------------------------------------------------------------
# Auction id:  24039
# Number of bids: 4
# Winning bid: 2938959.5
# Other bids: [2975374.2, 3055550.3, 3382487.99]
# Estimate: 2854000.0
# ----------------------------------------------------------------
# Opening  21825
# ----------------------------------------------------------------
# Auction id:  21825
# Number of bids: 3
# Winning bid: 2019305.0
# Other bids: [2475221.15, 2500000.0]
# Estimate: 2204476.0
# ----------------------------------------------------------------
# Opening  21657
# ----------------------------------------------------------------
# Auction id:  21657
# Number of bids: 5
# Winning bid: 2330855.24
# Other bids: [2417158.64, 2443976.32, 3137117.1, 3176159.25]
# Estimate: 2367440.0
# ----------------------------------------------------------------
# Opening  24425
# ----------------------------------------------------------------
# Auction id:  24425
# Number of bids: 4
# Winning bid: 4523363.45
# Other bids: [5421969.0, 5541765.0, 6197430.74]
# Estimate: 6397540.32
# ----------------------------------------------------------------
# Opening  24036
# ----------------------------------------------------------------
# Auction id:  24036
# Number of bids: 3
# Winning bid: 7525598.82
# Other bids: [8604721.0, 9194012.8]
# Estimate: 8340000.0
# ----------------------------------------------------------------
# Opening  25542
# ----------------------------------------------------------------
# Auction id:  25542
# Number of bids: 3
# Winning bid: 10791598.34
# Other bids: [11233000.0, 14550161.74]
# Estimate: 12300000.0
# ----------------------------------------------------------------
# Opening  23862
# ----------------------------------------------------------------
# Auction id:  23862
# Number of bids: 4
# Winning bid: 9459567.99
# Other bids: [10394114.0, 10669896.62, 10900567.32]
# Estimate: 8300000.0
# ----------------------------------------------------------------
# Opening  24956
# ----------------------------------------------------------------
# Auction id:  24956
# Number of bids: 3
# Winning bid: 2824931.56
# Other bids: [2827750.0, 3165243.25]
# Estimate: 2943356.5
# ----------------------------------------------------------------
# Opening  25873
# ----------------------------------------------------------------
# Auction id:  25873
# Number of bids: 1
# Winning bid: 1348751.9
# Other bids: []
# Estimate: 1620000.0
# ----------------------------------------------------------------
# Opening  25036
# ----------------------------------------------------------------
# Auction id:  25036
# Number of bids: 1
# Winning bid: 6657728.1
# Other bids: []
# Estimate: 6472679.5
# ----------------------------------------------------------------
# Opening  22907
# can only convert an array of size 1 to a Python scalar
# Opening  23465
# ----------------------------------------------------------------
# Auction id:  23465
# Number of bids: 4
# Winning bid: 4300000.0
# Other bids: [5577203.25, 6279174.0, 6361631.0]
# Estimate: 5398559.0
# ----------------------------------------------------------------
# Opening  24682
# ----------------------------------------------------------------
# Auction id:  24682
# Number of bids: 3
# Winning bid: 14264485.27
# Other bids: [15857724.22, 18867748.37]
# Estimate: 19300028.4
# ----------------------------------------------------------------
# Opening  25236
# ----------------------------------------------------------------
# Auction id:  25236
# Number of bids: 2
# Winning bid: 4408676.5
# Other bids: [5096891.65]
# Estimate: 6088206.4
# ----------------------------------------------------------------
# Opening  24620
# ----------------------------------------------------------------
# Auction id:  24620
# Number of bids: 7
# Winning bid: 18405711.55
# Other bids: [19062688.44, 19976086.3, 21715000.0, 22542467.0, 22861025.41, 25311266.0]
# Estimate: 17200000.0
# ----------------------------------------------------------------
# Opening  23513
# ----------------------------------------------------------------
# Auction id:  23513
# Number of bids: 2
# Winning bid: 13523000.0
# Other bids: [15744394.0]
# Estimate: 12307150.5
# ----------------------------------------------------------------
# Opening  24237
# ----------------------------------------------------------------
# Auction id:  24237
# Number of bids: 2
# Winning bid: 5028719.8
# Other bids: [5379008.8]
# Estimate: 5843695.3
# ----------------------------------------------------------------
# Opening  23423
# ----------------------------------------------------------------
# Auction id:  23423
# Number of bids: 2
# Winning bid: 6035626.55
# Other bids: [6698734.0]
# Estimate: 7802160.0
# ----------------------------------------------------------------
# Opening  24889
# ----------------------------------------------------------------
# Auction id:  24889
# Number of bids: 2
# Winning bid: 8097729.83
# Other bids: [8711003.8]
# Estimate: 9670558.52
# ----------------------------------------------------------------
# Opening  19164
# ----------------------------------------------------------------
# Auction id:  19164
# Number of bids: 6
# Winning bid: 2595839.0
# Other bids: [2857745.88, 2862180.27, 2899476.98, 3506600.0, 3540211.0]
# Estimate: 2650000.0
# ----------------------------------------------------------------
# Opening  24417
# ...
# Other bids: [1472326.0, 1495010.18]
# Estimate: 1400000.0
# ----------------------------------------------------------------
# Opening  25663
# ----------------------------------------------------------------
# Auction id:  25663
# Number of bids: 2
# Winning bid: 1105958.3
# Other bids: [1425964.48]
# Estimate: 1000000.0
# ----------------------------------------------------------------
# Opening  20907
# ----------------------------------------------------------------
# Auction id:  20907
# Number of bids: 4
# Winning bid: 3775000.0
# Other bids: [4614274.0, 4908367.0, 5142575.0]
# Estimate: 2986398.0
# ----------------------------------------------------------------
# Opening  24464
# ----------------------------------------------------------------
# Auction id:  24464
# Number of bids: 5
# Winning bid: 6229334.71
# Other bids: [7297780.5, 7319594.64, 7511826.7, 8251054.48]
# Estimate: 5500000.0
# ----------------------------------------------------------------
# Opening  24375
# ----------------------------------------------------------------
# Auction id:  24375
# Number of bids: 1
# Winning bid: 7587094.0
# Other bids: []
# Estimate: 5599748.5
# ----------------------------------------------------------------
# Opening  23160
# ----------------------------------------------------------------
# Auction id:  23160
# Number of bids: 1
# Winning bid: 11946689.77
# Other bids: []
# Estimate: 10697188.2
# ----------------------------------------------------------------
# Opening  24957
# ----------------------------------------------------------------
# Auction id:  24957
# Number of bids: 1
# Winning bid: 11849087.88
# Other bids: []
# Estimate: 11999999.99
# ----------------------------------------------------------------
# Opening  24771
# ----------------------------------------------------------------
# Auction id:  24771
# Number of bids: 3
# Winning bid: 2256065.0
# Other bids: [2295630.0, 2591637.5]
# Estimate: 2207650.0
# ----------------------------------------------------------------
# Opening  25918
# ----------------------------------------------------------------
# Auction id:  25918
# Number of bids: 6
# Winning bid: 3292634.21
# Other bids: [3434076.6, 3598000.0, 3658733.15, 3782491.0, 5014908.0]
# Estimate: 3802273.5
# ----------------------------------------------------------------
# Opening  25921
# ----------------------------------------------------------------
# Auction id:  25921
# Number of bids: 5
# Winning bid: 10329636.0
# Other bids: [10831940.09, 12418497.66, 14027965.13, 15980984.26]
# Estimate: 8100000.0
# ----------------------------------------------------------------
# Opening  24680
# ----------------------------------------------------------------
# Auction id:  24680
# Number of bids: 2
# Winning bid: 2200000.0
# Other bids: [3222220.0]
# Estimate: 2545767.0
# ----------------------------------------------------------------
# Opening  23689
# ----------------------------------------------------------------
# Auction id:  23689
# Number of bids: 4
# Winning bid: 1351993.0
# Other bids: [1496461.4, 1513407.1, 1687818.0]
# Estimate: 1262860.0
# ----------------------------------------------------------------
# Opening  21415
# ----------------------------------------------------------------
# Auction id:  21415
# Number of bids: 2
# Winning bid: 16532414.25
# Other bids: [17982600.24]
# Estimate: 15360840.5
# ----------------------------------------------------------------
# Opening  24321
# ----------------------------------------------------------------
# Auction id:  24321
# Number of bids: 7
# Winning bid: 4029066.8
# Other bids: [4067941.81, 4411916.04, 4662296.0, 4842638.49, 4958566.85, 5392295.5]
# Estimate: 5167292.0
# ----------------------------------------------------------------
# Opening  25874
# ----------------------------------------------------------------
# Auction id:  25874
# Number of bids: 2
# Winning bid: 1814282.0
# Other bids: [2287879.0]
# Estimate: 1900000.0
# ----------------------------------------------------------------
# Opening  23621
# ----------------------------------------------------------------
# Auction id:  23621
# Number of bids: 3
# Winning bid: 2035000.0
# Other bids: [2629921.72, 2701861.0]
# Estimate: 2460586.0
# ----------------------------------------------------------------
# Opening  21791
# ----------------------------------------------------------------
# Auction id:  21791
# Number of bids: 3
# Winning bid: 6297433.64
# Other bids: [7721535.59, 8303682.79]
# Estimate: 4800000.0
# ----------------------------------------------------------------
# Opening  23176
# ----------------------------------------------------------------
# Auction id:  23176
# Number of bids: 1
# Winning bid: 8097793.64
# Other bids: []
# Estimate: 7187399.0
# ----------------------------------------------------------------
# Opening  24535
# ----------------------------------------------------------------
# Auction id:  24535
# Number of bids: 4
# Winning bid: 1898279.0
# Other bids: [1958069.0, 1993080.0, 2272902.95]
# Estimate: 2300000.01
# ----------------------------------------------------------------
# Opening  25463
# ----------------------------------------------------------------
# Auction id:  25463
# Number of bids: 2
# Winning bid: 517741.0
# Other bids: [586497.21]
# Estimate: 351080.0
# ----------------------------------------------------------------
# Opening  25151
# ----------------------------------------------------------------
# Auction id:  25151
# Number of bids: 3
# Winning bid: 1850028.0
# Other bids: [2870000.0, 2996462.27]
# Estimate: 1500000.0
# ----------------------------------------------------------------
# Opening  21837
# ----------------------------------------------------------------
# Auction id:  21837
# Number of bids: 2
# Winning bid: 8614391.16
# Other bids: [9069209.12]
# Estimate: 8700000.0
# ----------------------------------------------------------------
# Opening  24148
# ----------------------------------------------------------------
# Auction id:  24148
# Number of bids: 5
# Winning bid: 2276811.91
# Other bids: [2397974.4, 2527270.76, 2689028.35, 3459906.0]
# Estimate: 2509255.0
# ----------------------------------------------------------------
# Opening  25832
# ----------------------------------------------------------------
# Auction id:  25832
# Number of bids: 3
# Winning bid: 2588099.25
# Other bids: [2690431.72, 3027683.95]
# Estimate: 2700000.0
# ----------------------------------------------------------------
# Opening  25789
# ----------------------------------------------------------------
# Auction id:  25789
# Number of bids: 1
# Winning bid: 1982586.35
# Other bids: []
# Estimate: 707750.0
# ----------------------------------------------------------------
# Opening  23542
# ----------------------------------------------------------------
# Auction id:  23542
# Number of bids: 3
# Winning bid: 5420000.0
# Other bids: [5444389.65, 6415496.05]
# Estimate: 5868027.29
# ----------------------------------------------------------------
# Opening  24598
# ----------------------------------------------------------------
# Auction id:  24598
# Number of bids: 3
# Winning bid: 1961623.67
# Other bids: [2741028.75, 2896275.83]
# Estimate: 3032255.0
# ----------------------------------------------------------------
# Opening  25541
# ----------------------------------------------------------------
# Auction id:  25541
# Number of bids: 2
# Winning bid: 1848693.0
# Other bids: [1894000.0]
# Estimate: 2000000.0
# ----------------------------------------------------------------
# Opening  25602
# ----------------------------------------------------------------
# Auction id:  25602
# Number of bids: 5
# Winning bid: 802142.5
# Other bids: [912773.0, 949999.0, 1058908.8, 1348955.0]
# Estimate: 1240000.0
# ----------------------------------------------------------------
# Opening  25081
# ----------------------------------------------------------------
# Auction id:  25081
# Number of bids: 4
# Winning bid: 1764435.35
# Other bids: [1794020.6, 1803825.26, 2761547.64]
# Estimate: 1769333.4
# ----------------------------------------------------------------
# Opening  24017
# ----------------------------------------------------------------
# Auction id:  24017
# Number of bids: 3
# Winning bid: 1716817.0
# Other bids: [1743369.2, 1757937.0]
# Estimate: 1770000.0
# ----------------------------------------------------------------
# Opening  22242
# ----------------------------------------------------------------
# Auction id:  22242
# Number of bids: 1
# Winning bid: 2021561.69
# Other bids: []
# Estimate: 3000000.0
# ----------------------------------------------------------------
# Opening  26259
# ----------------------------------------------------------------
# Auction id:  26259
# Number of bids: 4
# Winning bid: 1764960.5
# Other bids: [1847158.0, 2007055.45, 3005910.0]
# Estimate: 1994379.0
# ----------------------------------------------------------------
# Opening  24057
# ----------------------------------------------------------------
# Auction id:  24057
# Number of bids: 6
# Winning bid: 17879000.0
# Other bids: [18123585.4, 18842652.0, 19704480.95, 21438368.13, 21706720.08]
# Estimate: 16610060.0
# ----------------------------------------------------------------
# Opening  23560
# ----------------------------------------------------------------
# Auction id:  23560
# Number of bids: 2
# Winning bid: 14324912.69
# Other bids: [16888499.82]
# Estimate: 16563414.15
# ----------------------------------------------------------------
# Opening  24311
# ----------------------------------------------------------------
# Auction id:  24311
# Number of bids: 3
# Winning bid: 11244775.2
# Other bids: [11884450.35, 14266014.2]
# Estimate: 10634652.5
# ----------------------------------------------------------------
# Opening  23546
# ----------------------------------------------------------------
# Auction id:  23546
# Number of bids: 2
# Winning bid: 17781881.53
# Other bids: [20845330.26]
# Estimate: 16500000.0
# ----------------------------------------------------------------
# Opening  24668
# ----------------------------------------------------------------
# Auction id:  24668
# Number of bids: 2
# Winning bid: 1341361.0
# Other bids: [1552461.0]
# Estimate: 904550.0
# ----------------------------------------------------------------
# Opening  24232
# ----------------------------------------------------------------
# Auction id:  24232
# Number of bids: 1
# Winning bid: 1847077.3
# Other bids: []
# Estimate: 2100000.0
# ----------------------------------------------------------------
# Opening  22953
# ----------------------------------------------------------------
# Auction id:  22953
# Number of bids: 5
# Winning bid: 706289.0
# Other bids: [709540.4, 792524.5, 925282.0, 976335.5]
# Estimate: 542980.4
# ----------------------------------------------------------------
# Opening  25086
# ----------------------------------------------------------------
# Auction id:  25086
# Number of bids: 2
# Winning bid: 894364.0
# Other bids: [935714.0]
# Estimate: 900000.0
# ----------------------------------------------------------------
# Opening  22350
# ----------------------------------------------------------------
# Auction id:  22350
# Number of bids: 4
# Winning bid: 19259072.45
# Other bids: [19554435.85, 21111111.11, 22552208.19]
# Estimate: 15300000.0
# ----------------------------------------------------------------
# Opening  24684
# ----------------------------------------------------------------
# Auction id:  24684
# Number of bids: 2
# Winning bid: 2499779.84
# Other bids: [2630976.13]
# Estimate: 1903193.5
# ----------------------------------------------------------------
# Opening  25280
# ----------------------------------------------------------------
# Auction id:  25280
# Number of bids: 2
# Winning bid: 23979880.0
# Other bids: [34993871.02]
# Estimate: 21505150.0
# ----------------------------------------------------------------
# Opening  24418
# ----------------------------------------------------------------
# Auction id:  24418
# Number of bids: 2
# Winning bid: 5897002.35
# Other bids: [6214983.14]
# Estimate: 7308469.1
# ----------------------------------------------------------------
# Opening  25613
# ----------------------------------------------------------------
# Auction id:  25613
# Number of bids: 5
# Winning bid: 430695.9
# Other bids: [470445.2, 472708.5, 486601.0, 553774.0]
# Estimate: 499999.99
# ----------------------------------------------------------------
# Opening  25441
# ----------------------------------------------------------------
# Auction id:  25441
# Number of bids: 2
# Winning bid: 2299436.0
# Other bids: [2725835.56]
# Estimate: 2187517.0
# ----------------------------------------------------------------
# Opening  22827
# ----------------------------------------------------------------
# Auction id:  22827
# Number of bids: 4
# Winning bid: 49068138.24
# Other bids: [57056561.51, 57101000.0, 59730710.0]
# Estimate: 39500000.0
# ----------------------------------------------------------------
# Opening  25089
# ----------------------------------------------------------------
# Auction id:  25089
# Number of bids: 4
# Winning bid: 3897678.07
# Other bids: [4127646.0, 4525283.0, 5064521.6]
# Estimate: 3300000.0
# ----------------------------------------------------------------
# Opening  24518
# ----------------------------------------------------------------
# Auction id:  24518
# Number of bids: 1
# Winning bid: 4644427.21
# Other bids: []
# Estimate: 4644427.21
# ----------------------------------------------------------------
# Opening  24279
# ----------------------------------------------------------------
# Auction id:  24279
# Number of bids: 4
# Winning bid: 3896461.0
# Other bids: [4165966.5, 4573677.01, 4698218.0]
# Estimate: 2996661.0
# ----------------------------------------------------------------
# Opening  25093
# ----------------------------------------------------------------
# Auction id:  25093
# Number of bids: 3
# Winning bid: 21867076.31
# Other bids: [24562075.27, 28527754.94]
# Estimate: 26000003.0
# ----------------------------------------------------------------
# Opening  23567
# ----------------------------------------------------------------
# Auction id:  23567
# Number of bids: 4
# Winning bid: 8027827.75
# Other bids: [8514360.52, 9957345.87, 10354161.3]
# Estimate: 7909312.0
# ----------------------------------------------------------------
# Opening  23541
# ----------------------------------------------------------------
# Auction id:  23541
# Number of bids: 2
# Winning bid: 2012665.1
# Other bids: [2135550.0]
# Estimate: 1900000.0
# ----------------------------------------------------------------
# Opening  26357
# ----------------------------------------------------------------
# Auction id:  26357
# Number of bids: 3
# Winning bid: 497229.68
# Other bids: [545081.05, 589322.56]
# Estimate: 700000.0
# ----------------------------------------------------------------
# Opening  24622
# ----------------------------------------------------------------
# Auction id:  24622
# Number of bids: 4
# Winning bid: 11696658.61
# Other bids: [11985000.0, 12189799.71, 12242506.46]
# Estimate: 9500000.02
# ----------------------------------------------------------------
# Opening  25641
# ----------------------------------------------------------------
# Auction id:  25641
# Number of bids: 5
# Winning bid: 1311279.0
# Other bids: [1422164.75, 1423962.63, 1554475.69, 1563165.0]
# Estimate: 1350000.0
# ----------------------------------------------------------------
# Opening  23497
# ----------------------------------------------------------------
# Auction id:  23497
# Number of bids: 2
# Winning bid: 7358619.25
# Other bids: [8193656.0]
# Estimate: 7515475.5
# ----------------------------------------------------------------
# Opening  20867
# ----------------------------------------------------------------
# Auction id:  20867
# Number of bids: 1
# Winning bid: 16494822.0
# Other bids: []
# Estimate: 15992200.0
# ----------------------------------------------------------------
# Opening  24263
# ----------------------------------------------------------------
# Auction id:  24263
# Number of bids: 3
# Winning bid: 4623000.0
# Other bids: [4787329.01, 4921986.42]
# Estimate: 4500000.0
# ----------------------------------------------------------------
# Opening  25670
# ----------------------------------------------------------------
# Auction id:  25670
# Number of bids: 3
# Winning bid: 837006.0
# Other bids: [1106905.0, 1417396.36]
# Estimate: 837006.0
# ----------------------------------------------------------------

# %%
bids_df = pd.read_csv('bids1.csv')
bids_df.head()
# Out:
#    Auction  Num Bids         Eng  Lowest Bid      2_bid       3_bid  \
# 0    26055         2  1162614.00  1066564.50  1231284.0         NaN
# 1    20912         7  1800000.00  1747562.65  1870875.3  1878649.35
# 2    24881         2  2536283.06  2924208.00  3710384.2         NaN
# 3    24921         3  2800000.01  2895069.00  2988158.0  3898085.16
# 4    24063         5  4626079.20  3618938.30  3751213.5  3896707.40
#
#         4_bid       5_bid      6_bid      7_bid  8_bid  9_bid  10_bid
# 0         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 1  1889633.00  2391868.00  2397750.0  3325324.0    NaN    NaN     NaN
# 2         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 3         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 4  4150364.02  4766033.32        NaN        NaN    NaN    NaN     NaN

# %%
#Retrieve the vendor ranking table from old pdfs
outfile = 'bids2.csv'
dir2 = os.path.join(os.getcwd(), 'pdf_CDT')
read_pdfs(dir2, outfile=outfile, index = 0)
bids_df_old = pd.read_csv(outfile)
bids_df_old.head()
# Out:
# Opening 22437
# ----------------------------------------------------------------
# Auction id: 22437
# Number of bids: 5
# Winning bid: 1068716.0
# Other bids: [1076637.7, 1085869.0, 1168705.0, 1414966.0]
# Estimate: 768693.0
# ----------------------------------------------------------------
# Opening 23585
# ----------------------------------------------------------------
# Auction id: 23585
# Number of bids: 4
# Winning bid: 2154630.7
# Other bids: [2272702.31, 2385128.51, 2656006.72]
# Estimate: 2200255.3
# ----------------------------------------------------------------
# Opening 23485
# ----------------------------------------------------------------
# Auction id: 23485
# Number of bids: 7
# Winning bid: 4942712.29
# Other bids: [5013765.31, 5078192.25, 5352263.45, 5632142.0, 7358759.0, 9075974.0]
# Estimate: 6204360.5
# ----------------------------------------------------------------
# Opening 23112
# ----------------------------------------------------------------
# Auction id: 23112
# Number of bids: 2
# Winning bid: 1832965.0
# Other bids: [2071793.0]
# Estimate: 1550097.0
# ----------------------------------------------------------------
# Opening 23186
# ----------------------------------------------------------------
# Auction id: 23186
# Number of bids: 7
# Winning bid: 1710210.16
# Other bids: [1798693.64, 2054579.91, 2054960.0, 2120840.0, 2147241.25, 3121062.66]
# Estimate: 2224481.35
# ----------------------------------------------------------------
# Opening 21211
# ----------------------------------------------------------------
# Auction id: 21211
# Number of bids: 5
# Winning bid: 2841807.59
# Other bids: [3066537.15, 3221024.0, 3457161.7, 3586398.9]
# Estimate: 2600000.0
# ----------------------------------------------------------------
# Opening 23075
# ----------------------------------------------------------------
# Auction id: 23075
# Number of bids: 2
# Winning bid: 8973056.7
# Other bids: [10349858.45]
# Estimate: 8684203.0
# ----------------------------------------------------------------
# Opening 22188
# ----------------------------------------------------------------
# Auction id: 22188
# Number of bids: 2
# Winning bid: 1790122.0
# Other bids: [1899000.0]
# Estimate: 2200000.0
# ----------------------------------------------------------------
# Opening 22570
# ----------------------------------------------------------------
# Auction id: 22570
# Number of bids: 3
# Winning bid: 3594120.5
# Other bids: [4483133.9, 5078412.66]
# Estimate: 4499038.3
# ----------------------------------------------------------------
# Opening 23435
# ----------------------------------------------------------------
# Auction id: 23435
# Number of bids: 4
# Winning bid: 686000.0
# Other bids: [694288.0, 739245.82, 877963.0]
# Estimate: 992580.0
# ----------------------------------------------------------------
# Opening 24245
# ----------------------------------------------------------------
# Auction id: 24245
# Number of bids: 3
# Winning bid: 429287.6
# Other bids: [447131.1, 675252.0]
# Estimate: 450000.0
# ----------------------------------------------------------------
# Opening 23903
# ----------------------------------------------------------------
# Auction id: 23903
# Number of bids: 3
# Winning bid: 627740.25
# Other bids: [713898.45, 843128.0]
# Estimate: 600000.0
# ----------------------------------------------------------------
# Opening 23036
# ----------------------------------------------------------------
# Auction id: 23036
# Number of bids: 2
# Winning bid: 806793.0
# Other bids: [1242914.0]
# Estimate: 731875.91
# ----------------------------------------------------------------
# Opening 23419
# ----------------------------------------------------------------
# Auction id: 23419
# Number of bids: 3
# Winning bid: 483000.0
# Other bids: [483225.5, 633254.0]
# Estimate: 434270.0
# ----------------------------------------------------------------
# Opening 22399
# ----------------------------------------------------------------
# Auction id: 22399
# Number of bids: 6
# Winning bid: 3779170.0
# Other bids: [4134731.53, 4196705.71, 4197907.0, 4375711.45, 4964541.43]
# Estimate: 4103400.0
# ----------------------------------------------------------------
# Opening 21750
# ----------------------------------------------------------------
# Auction id: 21750
# Number of bids: 3
# Winning bid: 5021334.65
# Other bids: [5199380.95, 5339681.06]
# Estimate: 5898450.8
# ----------------------------------------------------------------
# Opening 24323
# ----------------------------------------------------------------
# Auction id: 24323
# Number of bids: 4
# Winning bid: 3872991.27
# Other bids: [4057775.9, 4760000.0, 4985368.89]
# Estimate: 6423997.0
# ----------------------------------------------------------------
# Opening 22966
# ----------------------------------------------------------------
# Auction id: 22966
# Number of bids: 2
# Winning bid: 10440648.0
# Other bids: [10623000.0]
# Estimate: 9799765.0
# ----------------------------------------------------------------
# Opening 23239
# ----------------------------------------------------------------
# Auction id: 23239
# Number of bids: 3
# Winning bid: 11321034.99
# Other bids: [11730276.46, 12178662.3]
# Estimate: 10025621.1
# ----------------------------------------------------------------
# Opening 21829
# ----------------------------------------------------------------
# Auction id: 21829
# Number of bids: 1
# Winning bid: 1349912.0
# Other bids: []
# Estimate: 1300000.0
# ----------------------------------------------------------------
# Opening 24427
# ----------------------------------------------------------------
# Auction id: 24427
# Number of bids: 4
# Winning bid: 392790.0
# Other bids: [496690.0, 595595.0, 675220.0]
# Estimate: 495000.0
# ----------------------------------------------------------------
# Opening 24075
# ----------------------------------------------------------------
# Auction id: 24075
# Number of bids: 1
# Winning bid: 1232369.26
# Other bids: []
# Estimate: 1232369.26
# ----------------------------------------------------------------
# Opening 22479
# ----------------------------------------------------------------
# Auction id: 22479
# Number of bids: 1
# Winning bid: 5284284.0
# Other bids: []
# Estimate: 5284284.0
# ----------------------------------------------------------------
# Opening 22734
# ----------------------------------------------------------------
# Auction id: 22734
# Number of bids: 4
# Winning bid: 8665314.0
# Other bids: [8843415.72, 8948045.55, 9184621.4]
# Estimate: 7959713.3
# ----------------------------------------------------------------
# Opening 20787
# ----------------------------------------------------------------
# Auction id: 20787
# Number of bids: 6
# Winning bid: 2152785.9
# Other bids: [2160531.5, 2230812.3, 2323994.5, 2455083.0, 2722131.0]
# Estimate: 2300000.0
# ----------------------------------------------------------------
# Opening 24400
# ----------------------------------------------------------------
# Auction id: 24400
# Number of bids: 1
# Winning bid: 30593034.49
# Other bids: []
# Estimate: 27642973.62
# ----------------------------------------------------------------
# Opening 24319
# ----------------------------------------------------------------
# Auction id: 24319
# Number of bids: 3
# Winning bid: 3246759.3
# Other bids: [3306780.4, 4236641.77]
# Estimate: 3513990.5
# ----------------------------------------------------------------
# Opening 23843
# ----------------------------------------------------------------
# Auction id: 23843
# Number of bids: 1
# Winning bid: 9775659.09
# Other bids: []
# Estimate: 9775659.09
# ----------------------------------------------------------------
# Opening 21776
# ----------------------------------------------------------------
# Auction id: 21776
# Number of bids: 2
# Winning bid: 4636611.0
# Other bids: [4887839.37]
# Estimate: 5700000.0
# ----------------------------------------------------------------
# Opening 23495
# ----------------------------------------------------------------
# Auction id: 23495
# Number of bids: 7
# Winning bid: 4617588.27
# Other bids: [4671634.36, 5372195.22, 5591738.15, 6234412.66, 9028697.91, 9599841.35]
# Estimate: 5783532.6
# ----------------------------------------------------------------
# Opening 21324
# ----------------------------------------------------------------
# Auction id: 21324
# Number of bids: 5
# Winning bid: 12336881.0
# Other bids: [13058000.0, 13520528.2, 14054767.8, 14107570.8]
# Estimate: 11000000.0
# ----------------------------------------------------------------
# Opening 24491
# ----------------------------------------------------------------
# Auction id: 24491
# Number of bids: 2
# Winning bid: 405363.9
# Other bids: [507256.8]
# Estimate: 328835.0
# ----------------------------------------------------------------
# Opening 21866ra
# ----------------------------------------------------------------
# Auction id: 21866ra
# Number of bids: 2
# Winning bid: 2163761.4
# Other bids: [2532551.36]
# Estimate: 2200000.0
# ----------------------------------------------------------------
# Opening 22435
# ----------------------------------------------------------------
# Auction id: 22435
# Number of bids: 3
# Winning bid: 1247572.0
# Other bids: [1307076.0, 1385732.0]
# Estimate: 1265197.0
# ----------------------------------------------------------------
# Opening 20900
# ----------------------------------------------------------------
# Auction id: 20900
# Number of bids: 6
# Winning bid: 1231602.06
# Other bids: [1324349.46, 1413125.5, 1531962.75, 1589859.0, 2406753.9]
# Estimate: 1316285.0
# ----------------------------------------------------------------
# Opening 24381
# ----------------------------------------------------------------
# Auction id: 24381
# Number of bids: 2
# Winning bid: 769386.25
# Other bids: [997509.0]
# Estimate: 819723.3
# ----------------------------------------------------------------
# Opening 24507
# ----------------------------------------------------------------
# Auction id: 24507
# Number of bids: 3
# Winning bid: 1436047.7
# Other bids: [1447482.28, 1492110.8]
# Estimate: 2000000.0
# ----------------------------------------------------------------
# Opening 21982
# ----------------------------------------------------------------
# Auction id: 21982
# Number of bids: 3
# Winning bid: 5157481.9
# Other bids: [5162000.0, 5527456.0]
# Estimate: 4400000.0
# ----------------------------------------------------------------
# Opening 23126
# ----------------------------------------------------------------
# Auction id: 23126
# Number of bids: 3
# Winning bid: 6394977.35
# Other bids: [6777161.05, 9525039.9]
# Estimate: 8028109.1
# ----------------------------------------------------------------
# Opening 23425
# ----------------------------------------------------------------
# Auction id: 23425
# Number of bids: 3
# Winning bid: 2173763.5
# Other bids: [2190556.0, 2908402.84]
# Estimate: 3028810.0
# ----------------------------------------------------------------
# Opening 22839
# ----------------------------------------------------------------
# Auction id: 22839
# Number of bids: 3
# Winning bid: 7450048.0
# Other bids: [7832765.35, 8378486.0]
# Estimate: 7800000.0
# ----------------------------------------------------------------
# Opening 22476
# ----------------------------------------------------------------
# Auction id: 22476
# Number of bids: 2
# Winning bid: 2429999.84
# Other bids: [2555000.0]
# Estimate: 2001445.0
# ----------------------------------------------------------------
# Opening 24254
# ----------------------------------------------------------------
# Auction id: 24254
# Number of bids: 1
# Winning bid: 539237.0
# Other bids: []
# Estimate: 495000.0
# ----------------------------------------------------------------
# Opening 21851
# ----------------------------------------------------------------
# Auction id: 21851
# Number of bids: 5
# Winning bid: 3519000.0
# Other bids: [3805560.66, 3970004.6, 3995379.09, 4334010.75]
# Estimate: 3528345.5
# ----------------------------------------------------------------
# Opening 21015
# ----------------------------------------------------------------
# Auction id: 21015
# Number of bids: 1
# Winning bid: 1568200.9
# Other bids: []
# Estimate: 1349718.0
# ----------------------------------------------------------------
# Opening 21832
# ----------------------------------------------------------------
# Auction id: 21832
# Number of bids: 3
# Winning bid: 827581.25
# Other bids: [917311.16, 1172372.9]
# Estimate: 1200000.0
# ----------------------------------------------------------------
# Opening apc
# list index out of range
# Opening 22859
# ----------------------------------------------------------------
# Auction id: 22859
# Number of bids: 4
# Winning bid: 1127477.0
# Other bids: [1242000.0, 1343304.15, 1609854.5]
# Estimate: 1650932.0
# ----------------------------------------------------------------
# Opening 20895
# ----------------------------------------------------------------
# Auction id: 20895
# Number of bids: 3
# Winning bid: 1975896.5
# Other bids: [1996779.81, 2897963.62]
# Estimate: 1499132.0
# ----------------------------------------------------------------
# Opening 23421r
# ----------------------------------------------------------------
# Auction id: 23421r
# Number of bids: 5
# Winning bid: 4148547.3
# Other bids: [4208039.2, 4475130.68, 4556111.8, 5110625.51]
# Estimate: 4600000.0
# ----------------------------------------------------------------
# Opening 23189
# ----------------------------------------------------------------
# Auction id: 23189
# Number of bids: 3
# Winning bid: 9731000.0
# Other bids: [10714890.39, 12400645.65]
# Estimate: 10000000.0
# ----------------------------------------------------------------
# Opening 22372
# ----------------------------------------------------------------
# Auction id: 22372
# Number of bids: 2
# Winning bid: 947425.8
# Other bids: [1173622.61]
# Estimate: 1005471.5
# ----------------------------------------------------------------
# Opening 24653
# ----------------------------------------------------------------
# Auction id: 24653
# Number of bids: 4
# Winning bid: 467197.75
# Other bids: [636415.0, 663253.0, 746590.0]
# Estimate: 495000.0
# ----------------------------------------------------------------
# Opening 19263
# ----------------------------------------------------------------
# Auction id: 19263
# Number of bids: 6
# Winning bid: 5353935.5
# Other bids: [5497330.56, 5973733.91, 6183272.15, 6379683.27, 8239887.84]
# Estimate: 5442678.0
# ----------------------------------------------------------------
# Opening 23668
# ----------------------------------------------------------------
# Auction id: 23668
# Number of bids: 4
# Winning bid: 1924290.0
# Other bids: [2167000.0, 2352132.8, 2530293.82]
# Estimate: 1966050.0
# ----------------------------------------------------------------
# Opening 22533
# ----------------------------------------------------------------
# Auction id: 22533
# Number of bids: 4
# Winning bid: 4882214.18
# Other bids: [5037466.87, 5140398.05, 5992427.5]
# Estimate: 5053542.1
# ----------------------------------------------------------------
# Opening 23676r
# ----------------------------------------------------------------
# Auction id: 23676r
# Number of bids: 3
# Winning bid: 1400899.0
# Other bids: [1456762.1, 1726642.7]
# Estimate: 974160.0
# ----------------------------------------------------------------
# Opening 23653
# ----------------------------------------------------------------
# Auction id: 23653
# Number of bids: 5
# Winning bid: 375686.0
# Other bids: [397999.0, 434434.2, 463116.0, 671506.0]
# Estimate: 400000.0
# ----------------------------------------------------------------
# Opening 22495
# ----------------------------------------------------------------
# Auction id: 22495
# Number of bids: 3
# Winning bid: 2728344.0
# Other bids: [2798206.0, 3079145.77]
# Estimate: 2039000.0
# ----------------------------------------------------------------
# Opening 22975
# ----------------------------------------------------------------
# Auction id: 22975
# Number of bids: 1
# Winning bid: 5272554.68
# Other bids: []
# Estimate: 4675088.0
# ----------------------------------------------------------------
# Opening 21861
# ----------------------------------------------------------------
# Auction id: 21861
# Number of bids: 3
# Winning bid: 1734605.84
# Other bids: [1858267.1, 1931466.35]
# Estimate: 1572275.5
# ----------------------------------------------------------------
# Opening 23522
# ----------------------------------------------------------------
# Auction id: 23522
# Number of bids: 7
# Winning bid: 26311514.56
# Other bids: [26345703.16, 27062135.31, 27830709.44, 29028600.0, 32077901.0, 33162021.0]
# Estimate: 25000000.0
# ----------------------------------------------------------------
# Opening 21854
# ----------------------------------------------------------------
# Auction id: 21854
# Number of bids: 2
# Winning bid: 5995456.29
# Other bids: [7298115.38]
# Estimate: 6030686.0
# ----------------------------------------------------------------
# Opening 24206
# ----------------------------------------------------------------
# Auction id: 24206
# Number of bids: 1
# Winning bid: 8482053.0
# Other bids: []
# Estimate: 8443623.5
# ----------------------------------------------------------------
# Opening 23699
# ----------------------------------------------------------------
# Auction id: 23699
# Number of bids: 1
# Winning bid: 1135158.0
# Other bids: []
# Estimate: 1087830.0
# ----------------------------------------------------------------
# Opening 23506
# ----------------------------------------------------------------
# Auction id: 23506
# Number of bids: 5
# Winning bid: 9098756.76
# Other bids: [9362816.23, 10170456.77, 10623946.6, 11941880.0]
# Estimate: 9347138.5
# ----------------------------------------------------------------
# Opening 22810
# ----------------------------------------------------------------
# Auction id: 22810
# Number of bids: 1
# Winning bid: 3289092.32
# Other bids: []
# Estimate: 2900000.0
# ----------------------------------------------------------------
# Opening 20821
# ----------------------------------------------------------------
# Auction id: 20821
# Number of bids: 5
# Winning bid: 3225150.78
# Other bids: [3329628.0, 3575682.71, 3847137.05, 4103775.69]
# Estimate: 3403498.4
# ----------------------------------------------------------------
# Opening 24095
# ----------------------------------------------------------------
# Auction id: 24095
# Number of bids: 4
# Winning bid: 450626.5
# Other bids: [498185.4, 529391.5, 533009.0]
# Estimate: 554410.0
# ----------------------------------------------------------------
# Opening 24304
# ----------------------------------------------------------------
# Auction id: 24304
# Number of bids: 1
# Winning bid: 7041298.06
# Other bids: []
# Estimate: 6470885.56
# ----------------------------------------------------------------
# Opening 23125
# ----------------------------------------------------------------
# Auction id: 23125
# Number of bids: 3
# Winning bid: 2777487.83
# Other bids: [2982133.0, 3399062.58]
# Estimate: 1803681.25
# ----------------------------------------------------------------
# Opening 22949
# ----------------------------------------------------------------
# Auction id: 22949
# Number of bids: 4
# Winning bid: 839139.0
# Other bids: [920224.0, 941408.0, 969898.0]
# Estimate: 806390.0
# ----------------------------------------------------------------
# Opening 23134
# ----------------------------------------------------------------
# Auction id: 23134
# Number of bids: 2
# Winning bid: 8716110.25
# Other bids: [10376741.33]
# Estimate: 6840598.5
# ----------------------------------------------------------------
# Opening 23673
# ----------------------------------------------------------------
# Auction id: 23673
# Number of bids: 6
# Winning bid: 9258933.37
# Other bids: [11873729.37, 12131124.35, 12861964.36, 13135492.88, 13815921.0]
# Estimate: 11544450.2
# ----------------------------------------------------------------
# Opening 22085
# ----------------------------------------------------------------
# Auction id: 22085
# Number of bids: 2
# Winning bid: 6242111.75
# Other bids: [7986980.95]
# Estimate: 5950302.9
# ----------------------------------------------------------------
# Opening 23280
# ----------------------------------------------------------------
# Auction id: 23280
# Number of bids: 5
# Winning bid: 2242550.0
# Other bids: [2510177.73, 2541677.4, 2567336.0, 2687230.0]
# Estimate: 2703090.0
# ----------------------------------------------------------------
# Opening 23037
# ----------------------------------------------------------------
# Auction id: 23037
# Number of bids: 4
# Winning bid: 1453444.63
# Other bids: [1657477.0, 1985210.0, 2386584.5]
# Estimate: 1651359.0
# ----------------------------------------------------------------
# Opening 22555
# ----------------------------------------------------------------
# Auction id: 22555
# Number of bids: 2
# Winning bid: 13545234.0
# Other bids: [13562192.8]
# Estimate: 17032967.45
# ----------------------------------------------------------------
# Opening 23062
# ----------------------------------------------------------------
# Auction id: 23062
# Number of bids: 2
# Winning bid: 2778251.0
# Other bids: [3318899.5]
# Estimate: 2056923.0
# ----------------------------------------------------------------
# Opening ifb
# can only convert an array of size 1 to a Python scalar
# Opening 23426
# ----------------------------------------------------------------
# Auction id: 23426
# Number of bids: 1
# Winning bid: 121174.0
# Other bids: []
# Estimate: 300000.0
# ----------------------------------------------------------------
# Opening 20694
# ----------------------------------------------------------------
# Auction id: 20694
# Number of bids: 6
# Winning bid: 1412234.07
# Other bids: [1608836.85, 1627119.17, 1946984.85, 1993518.86, 2378662.5]
# Estimate: 1351031.0
# ----------------------------------------------------------------
# Opening 24074
# ----------------------------------------------------------------
# Auction id: 24074
# Number of bids: 4
# Winning bid: 2115675.0
# Other bids: [2240875.0, 2671172.5, 2685317.5]
# Estimate: 2036655.0
# ----------------------------------------------------------------
# Opening 20628
# ----------------------------------------------------------------
# Auction id: 20628
# Number of bids: 4
# Winning bid: 3165324.0
# Other bids: [3644285.0, 3982477.98, 4055850.13]
# Estimate: 3263848.75
# ----------------------------------------------------------------
# Opening 22368r
# ----------------------------------------------------------------
# Auction id: 22368r
# Number of bids: 4
# Winning bid: 4489543.0
# Other bids: [4545431.25, 4817393.0, 5057000.0]
# Estimate: 4132527.0
# ----------------------------------------------------------------
# Opening 20952
# ----------------------------------------------------------------
# Auction id: 20952
# Number of bids: 4
# Winning bid: 2241203.0
# Other bids: [2286367.69, 2298169.65, 2771565.15]
# Estimate: 2076298.5
# ----------------------------------------------------------------
# Opening 23399
# ----------------------------------------------------------------
# Auction id: 23399
# Number of bids: 3
# Winning bid: 1287611.0
# Other bids: [1456278.0, 1462527.85]
# Estimate: 1176586.0
# ----------------------------------------------------------------
# Opening 22996
# ----------------------------------------------------------------
# Auction id: 22996
# Number of bids: 3
# Winning bid: 6178722.86
# Other bids: [6311977.22, 6730043.76]
# Estimate: 6200000.0
# ----------------------------------------------------------------
# Opening 24251
# ----------------------------------------------------------------
# Auction id: 24251
# Number of bids: 1
# Winning bid: 8666684.84
# Other bids: []
# Estimate: 8286089.12
# ----------------------------------------------------------------
# Opening 23103
# ----------------------------------------------------------------
# Auction id: 23103
# Number of bids: 2
# Winning bid: 9185527.9
# Other bids: [11075325.0]
# Estimate: 10700207.5
# ----------------------------------------------------------------
# Opening 23060
# ----------------------------------------------------------------
# Auction id: 23060
# Number of bids: 2
# Winning bid: 6331944.2
# Other bids: [6442274.36]
# Estimate: 6198999.7
# ----------------------------------------------------------------
# Opening 22166
# ----------------------------------------------------------------
# Auction id: 22166
# Number of bids: 2
# Winning bid: 1233396.66
# Other bids: [1469276.7]
# Estimate: 1100000.0
# ----------------------------------------------------------------
# Opening 24244
# ----------------------------------------------------------------
# Auction id: 24244
# Number of bids: 6
# Winning bid: 3243201.55
# Other bids: [3335103.83, 3536568.85, 3668336.85, 3739388.0, 4387433.84]
# Estimate: 3802740.0
# ----------------------------------------------------------------
# Opening 24428
# ----------------------------------------------------------------
# Auction id: 24428
# Number of bids: 2
# Winning bid: 258100.0
# Other bids: [337400.0]
# Estimate: 333300.0
# ----------------------------------------------------------------
# Opening 24297
# ----------------------------------------------------------------
# Auction id: 24297
# Number of bids: 1
# Winning bid: 4233606.16
# Other bids: []
# Estimate: 4233606.16
# ----------------------------------------------------------------
# Opening 24141
# ----------------------------------------------------------------
# Auction id: 24141
# Number of bids: 4
# Winning bid: 2999921.82
# Other bids: [3459293.25, 3970840.79, 4958769.03]
# Estimate: 4075129.0
# ----------------------------------------------------------------
# Opening 23124
# ----------------------------------------------------------------
# Auction id: 23124
# Number of bids: 2
# Winning bid: 2885726.1
# Other bids: [3031770.49]
# Estimate: 2610000.0
# ----------------------------------------------------------------
# Opening 22865
# ----------------------------------------------------------------
# Auction id: 22865
# Number of bids: 10
# Winning bid: 2627599.45
# Other bids: [2771562.4, 2852642.67, 2934293.8, 2992807.0, 3072761.33, 3144142.7, 3165916.95, 3284786.55, 3333285.0]
# Estimate: 2600000.0
# ----------------------------------------------------------------
# Opening 24500
# ----------------------------------------------------------------
# Auction id: 24500
# Number of bids: 3
# Winning bid: 1763226.0
# Other bids: [2288808.0, 2600000.0]
# Estimate: 2000000.0
# ----------------------------------------------------------------
# Opening 23109
# can only convert an array of size 1 to a Python scalar
# Opening 22796
# ----------------------------------------------------------------
# Auction id: 22796
# Number of bids: 4
# Winning bid: 4251133.2
# Other bids: [4377377.67, 4814651.5, 5710127.8]
# Estimate: 4000000.0
# ----------------------------------------------------------------
# Opening 20121
# ----------------------------------------------------------------
# Auction id: 20121
# Number of bids: 2
# Winning bid: 13278578.8
# Other bids: [14304613.5]
# Estimate: 13000886.75
# ----------------------------------------------------------------
# Opening 24338
# ----------------------------------------------------------------
# Auction id: 24338
# Number of bids: 3
# Winning bid: 2183681.75
# Other bids: [2186898.65, 2362267.05]
# Estimate: 2300000.0
# ----------------------------------------------------------------
# Opening 24367
# ----------------------------------------------------------------
# Auction id: 24367
# Number of bids: 1
# Winning bid: 10418752.22
# Other bids: []
# Estimate: 10418382.62
# ----------------------------------------------------------------
# Opening 22943
# ----------------------------------------------------------------
# Auction id: 22943
# Number of bids: 1
# Winning bid: 12613255.77
# Other bids: []
# Estimate: 11033818.3
# ----------------------------------------------------------------
# Opening 23490
# ----------------------------------------------------------------
# Auction id: 23490
# Number of bids: 3
# Winning bid: 21982066.35
# Other bids: [24743109.8, 24961248.3]
# Estimate: 20623355.9
# ----------------------------------------------------------------
# Opening 23321r
# ----------------------------------------------------------------
# Auction id: 23321r
# Number of bids: 5
# Winning bid: 6134943.74
# Other bids: [6613279.75, 6916909.0, 6992566.2, 9563438.32]
# Estimate: 6600000.0
# ----------------------------------------------------------------
# Opening 20898
# ----------------------------------------------------------------
# Auction id: 20898
# Number of bids: 2
# Winning bid: 825874.03
# Other bids: [1187604.5]
# Estimate: 389706.5
# ----------------------------------------------------------------
# Opening 24219
# can only convert an array of size 1 to a Python scalar
# Opening 22995
# ----------------------------------------------------------------
# Auction id: 22995
# Number of bids: 10
# Winning bid: 1373919.9
# Other bids: [1457347.0, 1457792.3, 1544908.0, 1569224.0, 1606678.97, 1609035.15, 1678853.9, 1824000.0, 1863581.25]
# Estimate: 1800000.0
# ----------------------------------------------------------------
# Opening 23500
# ----------------------------------------------------------------
# Auction id: 23500
# Number of bids: 3
# Winning bid: 8032745.27
# Other bids: [8959413.0, 10167175.8]
# Estimate: 8759098.92
# ----------------------------------------------------------------
# Opening 22712
# ----------------------------------------------------------------
# Auction id: 22712
# Number of bids: 1
# Winning bid: 11537166.8
# Other bids: []
# Estimate: 11537166.8
# ----------------------------------------------------------------
# Opening 21986
# ----------------------------------------------------------------
# Auction id: 21986
# Number of bids: 5
# Winning bid: 13636670.6
# Other bids: [14122333.85, 14299999.99, 15065755.35, 15333553.23]
# Estimate: 13501000.0
# ----------------------------------------------------------------
# Opening 24093
# ----------------------------------------------------------------
# Auction id: 24093
# Number of bids: 3
# Winning bid: 996991.45
# Other bids: [1075667.5, 1406118.0]
# Estimate: 906503.5
# ----------------------------------------------------------------
# Opening 23355
# ----------------------------------------------------------------
# Auction id: 23355
# Number of bids: 3
# Winning bid: 900069.0
# Other bids: [1131946.0, 1176051.0]
# Estimate: 1032745.0
# ----------------------------------------------------------------
# Opening 23605
# ----------------------------------------------------------------
# Auction id: 23605
# Number of bids: 1
# Winning bid: 18285665.17
# Other bids: []
# Estimate: 18285665.17
# ----------------------------------------------------------------
# Opening 22845
# ----------------------------------------------------------------
# Auction id: 22845
# Number of bids: 3
# Winning bid: 6421280.1
# Other bids: [6983248.3, 7584859.7]
# Estimate: 7080602.2
# ----------------------------------------------------------------
# Opening 23675
# ----------------------------------------------------------------
# Auction id: 23675
# Number of bids: 2
# Winning bid: 2755466.0
# Other bids: [2903990.0]
# Estimate: 2213575.0
# ----------------------------------------------------------------
# Opening 24472
# ----------------------------------------------------------------
# Auction id: 24472
# Number of bids: 3
# Winning bid: 2621686.25
# Other bids: [2768113.86, 3070864.1]
# Estimate: 2004849.5
# ----------------------------------------------------------------
# Opening 23067
# ----------------------------------------------------------------
# Auction id: 23067
# Number of bids: 4
# Winning bid: 7018011.26
# Other bids: [7196818.4, 7581000.0, 7968137.35]
# Estimate: 9230184.0
# ----------------------------------------------------------------
# Opening 24053r
# ----------------------------------------------------------------
# Auction id: 24053r
# Number of bids: 2
# Winning bid: 2264126.0
# Other bids: [2872720.0]
# Estimate: 2289794.0
# ----------------------------------------------------------------
# Opening 23169
# ----------------------------------------------------------------
# Auction id: 23169
# Number of bids: 6
# Winning bid: 8210403.86
# Other bids: [8552999.1, 8750996.2, 8923770.38, 8991379.0, 11198619.36]
# Estimate: 8635332.1
# ----------------------------------------------------------------
# Opening 23841
# ----------------------------------------------------------------
# Auction id: 23841
# Number of bids: 1
# Winning bid: 64489476.5
# Other bids: []
# Estimate: 64489475.58
# ----------------------------------------------------------------
# Opening 23922r
# ----------------------------------------------------------------
# Auction id: 23922r
# Number of bids: 4
# Winning bid: 1100750.0
# Other bids: [1245289.6, 1280000.0, 1284642.0]
# Estimate: 1333156.0
# ----------------------------------------------------------------
# Opening 22210
# ----------------------------------------------------------------
# Auction id: 22210
# Number of bids: 3
# Winning bid: 9696572.28
# Other bids: [10983042.28, 12858484.07]
# Estimate: 9919000.0
# ----------------------------------------------------------------
# Opening 22443
# ----------------------------------------------------------------
# Auction id: 22443
# Number of bids: 3
# Winning bid: 384987.5
# Other bids: [405000.0, 760330.0]
# Estimate: 328845.0
# ----------------------------------------------------------------
# Opening 21572
# ----------------------------------------------------------------
# Auction id: 21572
# Number of bids: 3
# Winning bid: 4047183.1
# Other bids: [4129091.26, 4700000.0]
# Estimate: 4524735.7
# ----------------------------------------------------------------
# Opening 21795
# ----------------------------------------------------------------
# Auction id: 21795
# Number of bids: 1
# Winning bid: 11566137.7
# Other bids: []
# Estimate: 11762536.75
# ----------------------------------------------------------------
# Opening 21907
# ----------------------------------------------------------------
# Auction id: 21907
# Number of bids: 6
# Winning bid: 28491838.57
# Other bids: [29078285.55, 29959353.9, 30235918.17, 31339477.08, 33966085.0]
# Estimate: 27586294.4
# ----------------------------------------------------------------
# Opening 23178
# ----------------------------------------------------------------
# Auction id: 23178
# Number of bids: 3
# Winning bid: 12833876.9
# Other bids: [13286170.47, 13495866.16]
# Estimate: 12500586.55
# ----------------------------------------------------------------
# Opening 23005
# ----------------------------------------------------------------
# Auction id: 23005
# Number of bids: 8
# Winning bid: 1192142.1
# Other bids: [1329977.3, 1356071.0, 1376998.62, 1445577.0, 1465423.82, 1567845.0, 1600000.0]
# Estimate: 1500000.0
# ----------------------------------------------------------------
# Opening 24062
# ----------------------------------------------------------------
# Auction id: 24062
# Number of bids: 3
# Winning bid: 473829.0
# Other bids: [479843.8, 500000.0]
# Estimate: 478554.0
# ----------------------------------------------------------------
# Opening 17881c
# ----------------------------------------------------------------
# Auction id: 17881c
# Number of bids: 3
# Winning bid: 26104984.43
# Other bids: [28271548.65, 32500734.12]
# Estimate: 31323797.51
# ----------------------------------------------------------------
# Opening 23865
# ----------------------------------------------------------------
# Auction id: 23865
# Number of bids: 4
# Winning bid: 1086039.0
# Other bids: [1457538.0, 1499988.5, 1535924.5]
# Estimate: 1136277.0
# ----------------------------------------------------------------
#   Auction  Num Bids         Eng  Lowest Bid       2_bid       3_bid  \
# 0   22437         5   768693.00  1068716.00  1076637.70  1085869.00
# 1   23585         4  2200255.30  2154630.70  2272702.31  2385128.51
# 2   23485         7  6204360.50  4942712.29  5013765.31  5078192.25
# 3   23112         2  1550097.00  1832965.00  2071793.00         NaN
# 4   23186         7  2224481.35  1710210.16  1798693.64  2054579.91
#
#         4_bid      5_bid       6_bid       7_bid  8_bid  9_bid  10_bid
# 0  1168705.00  1414966.0         NaN         NaN    NaN    NaN     NaN
# 1  2656006.72        NaN         NaN         NaN    NaN    NaN     NaN
# 2  5352263.45  5632142.0  7358759.00  9075974.00    NaN    NaN     NaN
# 3         NaN        NaN         NaN         NaN    NaN    NaN     NaN
# 4  2054960.00  2120840.0  2147241.25  3121062.66    NaN    NaN     NaN

# %%
#Merging new and old dataframes based on auction id.
overlap = set(bids_df['Auction']).intersection(bids_df_old['Auction'])
df_unique = bids_df_old[~bids_df_old['Auction'].isin(overlap)]
merged_df = pd.concat([bids_df, df_unique], ignore_index=True)
merged_df.to_csv('bids_final.csv')
merged_df = merged_df.dropna(axis=1, how='all')
merged_df.head()
# Out:
#   Auction  Num Bids         Eng  Lowest Bid      2_bid       3_bid  \
# 0   26055         2  1162614.00  1066564.50  1231284.0         NaN
# 1   20912         7  1800000.00  1747562.65  1870875.3  1878649.35
# 2   24881         2  2536283.06  2924208.00  3710384.2         NaN
# 3   24921         3  2800000.01  2895069.00  2988158.0  3898085.16
# 4   24063         5  4626079.20  3618938.30  3751213.5  3896707.40
#
#         4_bid       5_bid      6_bid      7_bid  8_bid  9_bid  10_bid
# 0         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 1  1889633.00  2391868.00  2397750.0  3325324.0    NaN    NaN     NaN
# 2         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 3         NaN         NaN        NaN        NaN    NaN    NaN     NaN
# 4  4150364.02  4766033.32        NaN        NaN    NaN    NaN     NaN
